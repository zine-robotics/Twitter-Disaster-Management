# %%
import re

import numpy as np
import pandas as pd
from nltk.tokenize import TweetTokenizer
from nltk import pos_tag, ne_chunk
from nltk.chunk import conlltags2tree, tree2conlltags
from nltk.tag.stanford import StanfordNERTagger
import nltk

from tqdm import *
from pprint import pprint

# %% [markdown]
# Getting all the tweets from the twitter api and then saving it here

# %%
tweets = pd.read_csv('./tweet.csv',encoding='ISO-8859-1')

# %% [markdown]
# ## Data Preprocessing

# %%
tweets.dropna(axis=0, subset=['retweets'],inplace=True)
tweets.head()
# Out:
#               date         username  retweets  \
# 0    6/5/2019 3:26         mchellap         1
# 1   6/4/2019 16:10      SRKKeralaFC        30
# 2   6/4/2019 14:55  NewIndianXpress         2
# 3    6/3/2019 6:55      JustOutNews         0
# 4  5/29/2019 16:22   Alonzo10541251         0
#
#                                                 text  \
# 0  The western ghats policy that wasn't implement...
# 1  Schools are gonna open this week all over Kera...
# 2  Local self-government institutions and governm...
# 3  Govt to construct four new dams in Kerala; aim...
# 4  Thubten Chodron speaks against Dagri Rinpoche....
#
#                         mentions  \
# 0                            NaN
# 1               @SRKCHENNAIFCpic
# 2                            NaN
# 3  @CPIMKerala @keralagovernment
# 4                            NaN
#
#                                             hashtags
# 0                                      #Keralafloods
# 1                                      #KeralaFloods
# 2                             #Wayanad #KeralaFloods
# 3  #kerala #keralafloods #StateNews #CurrentUpdat...
# 4  #AwardWapsiExposed #SonOfTadipar #instagood #l...

# %% [markdown]
# Extracting text from the tweets dataframe
#
# Removing URLs, Removing @..., and the hashtags

# %%
tweets.text = tweets.text.apply(lambda x: re.sub(u'https:\S+', u'', x))
tweets.text = tweets.text.apply(lambda x: re.sub(u'http:\S+', u'', x))
tweets.text = tweets.text.apply(lambda x: re.sub(u'(\s)@\w+', u'', x))
tweets.text = tweets.text.apply(lambda x: re.sub(u'#', u'', x))
for text in tweets.text.tail(70):
    print(text + '\n')
# Out:
# All Kerala Ajith Fans Kodumbu unit distributed Food and other Relief materials to KeralaFloods victims. pic.twitter.com/DLOx8wSfvw
#
# RSS Swayamsevaks working day and night to rescue the flood affected people in Kerala. Supplies of rice pulses sugar & medicines etc continues in several districts of Kerala. KeralaFloodRelief KeralaFloods pic.twitter.com/fA5i3b7aKo
#
# Palakkad Thala Ajith fans Kodumbu unit provided relief materials to those who are affected by KeralaFloods pic.twitter.com/3sVnudB6Wt
#
# See how Kerala's Hindu community reacted to Sangh Parivar's hate campaign to refrain from making donations to the KeralaFloods This is why we Sanghis hate entire Kerala. Anti National Mallus  â¦
#
# Humanity is still alive.. KeralaFloods pic.twitter.com/SAItU3eTjS
#
# Everything you dumped  eventually returned to you KeralaFloods pic.twitter.com/KpwBv0sHIn
#
# RT & SHARE KeralaFloods Helpline Numbers kerala Chief Ministerâs Distress Relief Fund A/c No : 67319948232 Bank : SBI City Branch TVM IFSC : SBIN0070028 Help kerala.twitter.com/EZF04JdFN1
#
# Video of the Day! Meet NDRF personnel Kanhaiya Kumar the who ran across a road with an ailing kid moments before the road was submerged by water. The child was suffering from high fever and had to be shifted to a nearby hospital. Unsung Heroes! KeralaFloods pic.twitter.com/q28p2CfAzV
#
# â¢ We NorthChennaiSFC planning To Send 10K Biscuit Packets & 5K Milk Powder Packets to Kerala for Flood Relief Camp ..As Of Now 4K Biscuit Packets & 500 Milkpowder Packets are ready! Will update about it soon KeralaFloods KeralaRains.twitter.com/cfL32rQIML
#
# There are unprecedented floods in Kerala causing huge damage. We have decided that as the situation becomes normal passports damaged on account floods shall be replaced free of charge. Please contact the concerned Passport Kendras. KeralaFloods Pls RT
#
# Home Minister to visit the flood-affected areas of Kerala today. 14 NDRF teams deployed; seven rescued 398 others and 12 livestock evacuated  â¦ KeralaFloods KeralaFloodReliefpic.twitter.com/Xl2bCCofiJ
#
# Today when is helping citizens struck in KeralaFloods where are the leftist & ?? Busy campaigning for elections in Rajasthan And they named RSS as Hindu terrorism I am proud of helping all irrespective of religion or caste.
#
# Thalapathy Vijay fans are actively into relief rehabilitation and charity work for the KeralaFloods.. Kerala VMI  â¦
#
# Nammavar & donate â¹50 lacs [â¹25L each] to the Chief Ministers Distress Relief Fund Kerala. Great gesture KeralaFloods2018 KeralaFloodRelief KeralaFloods pic.twitter.com/6XfiOybSyX
#
# Shocking Christians Refused to Dine with Dalits: CPM Leaders Set Up Separate Relief Camp KeralaFloods KeralaFloods2018 KeralaRain â¦
#
# My deepest condolences to the families of those killed in the devastating KeralaFloods. Praying for your safety and the success of those involved in relief efforts.
#
# Saving their lives was our priority. Now it is our duty to help them rebuild it. Contribute generously to the Chief Minister's Distress Relief Fund. KeralaFloods KeralaFloodReliefpic.twitter.com/eNHjyENt8d
#
# The hero of the day is Kanayya Kumar(Bihar) a personel who risked himself to save a child. The above frame is the current talking point in Kerala. KeralaFloods pic.twitter.com/aPbvz4MJpu
#
# Kerala Christians and Muslims are well known for their hatred of Hindus. With most of Kerala under water they have no problems accepting help from the and other Sanghis. KeralaFloods pic.twitter.com/kjEjfBrhbO
#
# Instant Response by and donate to rain ravaged KeralaFloods KeralaFloodRelief â¦
#
# Actors and donate 25 Lakhs to Kerala Chief Minister Disaster Relief fund to help the people affected by KeralaFloods Great gesture
#
# Kudos and for standing up to a worrying issue. The brothers have donated INR 25 lakhs towards the KeralaFloods relief fund.
#
# Generous brothers & have contributed a total of 25 lakhs to the Kerala CM relief fund for the KeralaFloods
#
# Wonderful gesture by brothers and . They have donated 25 lakhs for KeralaFloods relief work !! Long live both !! . pic.twitter.com/X8tZemSFtG
#
# BREAKING : In response to KeralaFloods happening now & has announced to donate a sum of 25 lakhs to Chief minister's distress relief fund!! KeralaFloodRelief
#
# . & donates 25 lakhs to Kerala people for KeralaFloods ! pic.twitter.com/6JNfZT4MKh
#
# Let's pray our brother's & sister's who are suffering in Kerala flood Stay safe & be strong KeralaRain KeralaFloods pic.twitter.com/3yu4rqRs2H
#
# Superstar fans have sent relief materials to those affected by KeralaFloods Kudos to the Team.. pic.twitter.com/TKmWWafHIE
#
# RSS Swayamsevaks in rescue works at Flood hit zones of Kerala. KeralaFloods RSSinActionpic.twitter.com/sRaN416h2t
#
# Wishing and praying for the safety and well being of all those affected by the rain and floods !! godsaveyourowncountry kerala keralafloods
#
# Some heroes don't wear masks Meet Vishnu from Madhya Pradesh who donated all the sheets he brought to sell to those suffering from the floods Hero KeralaFloods pic.twitter.com/hFSgwt0w5M
#
# Heavy rains in Kerala...hoping and praying for everything to become normal soon..People there pls stay safe.. KeralaFloods KeralaRainpic.twitter.com/U2Fl4XEjzV
#
# RSS Swayamsevaks rushed in for rescue works at various Flood hit zones in Kerala helped and served the flood effected Citizens with Food Shelter etc. KeralaFloods KeralaRain.twitter.com/8SP7kB4wEL
#
# Kerala is in the midst of an unprecedented rain havoc. Path to recovery can be long & arduous but you can make a difference by joining the rebuilding efforts. CM Pinarayi Vijayan has urged all to contribute generously to the Chief Minister's Distress Relief Fund. KeralaFloods pic.twitter.com/kvDgBwWEfl
#
# . is extending all possible assistance to the people affected by landslides and KeralaFloods through Humanitarian Assistance Disaster Relief HADR missions. IAF will continue to provide HADR till the situation is normalized. FloodRelief  pic.twitter.com/kTWk3l0g9s
#
# Raingods don't care about your relegion! KeralaFloods pic.twitter.com/QorZ5H7Dmi
#
# Whatever it takes we're there! Think twice before you question IndianArmy next time. KeralaFloods pic.twitter.com/T4ObsGJevE
#
# I can't help but notice how some RSS sympathisers are spewing venom during KeralaFloods . The interesting part is most of them are not even Malayalis but make sweeping statements like RSS workers are handling relief operations while the gov is not doing anything. Such blindness
#
# A quick reaction rescue team of 122 TA Battallion of Kannur has been carrying massive rescue operations. The undaunted selfless service of these soldiers of India is really commendable and we are highly proud of our brave hearts - "The Kannur Terriers" keralarains KeralaFloods pic.twitter.com/vdcwenFHDG
#
# UPDATE | keralarains play havoc: All five shutters of Idukki dam opened for first time in 40 years KeralaFloods pic.twitter.com/byoJxwfqKf
#
# Whatever it Takes. Salute KeralaFloods pic.twitter.com/4ced62NgwW
#
# I spoke to Kerala CM he is fully satisfied with the assistance of the central govt & he has told me that every department is cooperating well. If he needs any other assistance he will inform me: Union Home Minister Rajnath Singh on KeralaFloods pic.twitter.com/54sIA61rji
#
# A simplified flowchart of the Idukki group of reservoirs. Maybe useful for those writing on KeralaFloods pic.twitter.com/yD6L0k9InM
#
# Updates: Heavy rains continue to batter Kerala 24 dams opened across state. We will give you minute by minute update of what's happening in Kerala. Do follow this blog. KeralaFloods  â¦
#
# Two more shutters of the Idukki dam were opened today morning increasing the water flow into Periyar river to 125 cuses (125000 ltres/sec) ANI images from Idukki as heavy rain continues to lash Kerala. KeralaFloods pic.twitter.com/Qnan6AkAHl
#
# LIVE KeralaFloods | 26 dead Kochi on high alert as more shutters of Idukki dam opened Follow more updates here:  pic.twitter.com/Bx8HOPbitR
#
# â¢ Stay Safe Everyone..Here are the Helpline Numbers..! Share KeralaFloods KeralaRains.twitter.com/9W7ZpMnKP9
#
# Happiness is everywhere KeralaRains KeralaFloods pic.twitter.com/NxAwgwWGhU
#
# Share ... helpline numbers KeralaFloods keralarainspic.twitter.com/8Xy2VcBpiX
#
# There has been unprecedented floods in Kerala since y'day & incessant rains for 2 weeks. It is the biggest rain we had in 50 years.22 people died.Armed forces to fly to Kerala immediately6 central rescue teams already there.All the dams opened:Union Min KJ Alphons KeralaFloods pic.twitter.com/HYrRmXmEld
#
# The fury of Nature. Bharatapuzha river flowing over the iconic and ever busy Pattambi bridge. keralarains KeralaFloods Keralapic.twitter.com/xHNnc1uBBA
#
# KeralaRain One shutter of the Cheruthoni Dam a part of the dam system of the Idukki hydel reservoir opened after 26 years following heavy rains. KeralaFloods.twitter.com/QgcjLmMxVK
#
# The ingenious Malayali will never leave a chance. Fishing at Palakkad bus stand Keralafloods pic.twitter.com/RjRamUCQq8
#
# Historic Moment After 26 years shutters of the IdukkiDam opened for trial run as water level rises up to nearly 2399 ft in the reservoir. One of the 5 Shutters the middle shutter of the Cheruthoni dam has been lifeted up by 50cm for trial Run. KeralaFloods keralaRainspic.twitter.com/oeJeET39as
#
# Flood alert: Cochin International Airport stops arrival operations as a precautionary measure keralarains KeralaFloods EdamalayarDam Kerala CIALpic.twitter.com/CNBRepv9sx
#
# Idukki dam shutters opened. Trial run started Idukki IDUKKIDAM IDAMALAYAR EdamalayarDam periyar waterlever Keralarains KeralaFloods pic.twitter.com/dcTWyg5VwA
#
# BREAKING: After 26 years shutters of the IdukkiDam opened for trial run as water level rises up to nearly 2399 ft in the reservoir. One of the 5 Shutters the middle shutter of the Cheruthoni dam has been lifeted up by 50cm for trial Run. KeralaFloods keralaRainspic.twitter.com/0PX9vMb19M
#
# 10 people were killed in landslides in Idukki five in Malappuram two in Kannur and one in Wayanad district. KeralaFloods  â¦
#
# 20 people die in Kerala owing to flooding and landslides following heavy and incessant rains keralarains KeralaFloods
#
# KeralaFloods -truly flooded it is!! climatechange
#
# idukki dam shutters opened alert issued in Kerala  KeralaFloods keralarains
#
# idukki dams third shutter opened for first time in 26 years in Kerala Flooding likely in periyar and aluva KeralaFloods
#
# KeralaFloods | Most of the casualties have been reported from Idukki district in central Kerala with 10 deaths  â¦
#
# KeralaFloods: Heavy rainfall landslides kill at least 18 â¦
#
# 16 people died in heavy rains in Wayanad. There are sad news reports from Kerala. KeralaRains KeralaFloods  â¦
#
# Whatâs this professional college shit in Kerala? Every time collector announces holidays due to rains etc professional colleges are exception. Donât they have any concern for their safety KeralaFloods
#
# Kerala hits heavy rains. KeralaFloods 13 deaths reported and 8 missing across the states. Dams shutter opened to lesser calamity. Huge loses incurred. have taken measures to ensure safety and minimise lose. A new state development plan should be created for future.pic.twitter.com/PImfwnfUF5
#
# Palakkad records 214 mm rainfall for the 24 hours ending today morning 8:30 AM. Thats just about 20 mm short of highest recorded 24 hour rainfall in the city 236 mm way back in May 1957 no wonder most areas are seeing floods Keralafloods Kerala COMKpic.twitter.com/pbmV7aHfyK
#
# They're catching FISH!! THESE GUYS ARE INSANE. They're using our mango grabbing basket-thingy to catch fish. Wait is that my parents? GlobalWarming KeralaFloods pic.twitter.com/qaezXISo44
#
# Palakkad is siiinking!!! The prophecy is true. My neighbours standing outside. Watching our neighbourhood flood. Least bothered about their lives. Stay at home foolish people. Yes I'm okay guys. GlobalWarming KeralaFloods pic.twitter.com/61wGbD5A4w

# %% [markdown]
# ## Tokenizing with nltk

# %%
tknzr = TweetTokenizer()

nltk_tweets = []
for text in tweets.text:
    nltk_tweets.append(tknzr.tokenize(text))
nltk_tweets[-68]
# Out:
# ['Palakkad',
#  'Thala',
#  'Ajith',
#  'fans',
#  'Kodumbu',
#  'unit',
#  'provided',
#  'relief',
#  'materials',
#  'to',
#  'those',
#  'who',
#  'are',
#  'affected',
#  'by',
#  'KeralaFloods',
#  'pic.twitter.com/3sVnudB6Wt']

# %%
#nltk.download()

# %% [markdown]
# Using POS tagger to get the array of various part of speech in the tweet

# %%
nltk_pos = []

for text in nltk_tweets:
    nltk_pos.append(pos_tag(text))
pprint(nltk_pos[-68])
#print(ne_chunk(nltk_pos[-68]))
# Out:
# [('Palakkad', 'NNP'),
#  ('Thala', 'NNP'),
#  ('Ajith', 'NNP'),
#  ('fans', 'NNS'),
#  ('Kodumbu', 'NNP'),
#  ('unit', 'NN'),
#  ('provided', 'VBD'),
#  ('relief', 'NN'),
#  ('materials', 'NNS'),
#  ('to', 'TO'),
#  ('those', 'DT'),
#  ('who', 'WP'),
#  ('are', 'VBP'),
#  ('affected', 'VBN'),
#  ('by', 'IN'),
#  ('KeralaFloods', 'NNP'),
#  ('pic.twitter.com/3sVnudB6Wt', 'NN')]

# %% [markdown]
# Tried Named entity recognition using NLTK but not accurate

# %%
nltk_pos
# Out:
# [[('The', 'DT'),
#   ('western', 'JJ'),
#   ('ghats', 'NNS'),
#   ('policy', 'NN'),
#   ('that', 'IN'),
#   ("wasn't", 'NN'),
#   ('implemented', 'VBD'),
#   ('-', ':'),
#   ('possibly', 'RB'),
#   ('causing', 'VBG'),
#   ('the', 'DT'),
#   ('Keralafloods', 'NNP'),
#   ('?', '.'),
#   ('Curious', 'NNP'),
#   ('-', ':'),
#   ('do', 'VBP'),
#   ('you', 'PRP'),
#   ('feel', 'VB'),
#   ('it', 'PRP'),
#   ('didnt', 'VB'),
#   ('go', 'VB'),
#   ('far', 'RB'),
#   ('enough', 'RB'),
#   ('?', '.')],
#  [('Schools', 'NNS'),
#   ('are', 'VBP'),
#   ('gonna', 'JJ'),
#   ('open', 'JJ'),
#   ('this', 'DT'),
#   ('week', 'NN'),
#   ('all', 'DT'),
#   ('over', 'IN'),
#   ('Kerala', 'NNP'),
#   ('.', '.'),
#   ('We', 'PRP'),
#   ('distributed', 'VBD'),
#   ('bags', 'NNS'),
#   ('and', 'CC'),
#   ('study', 'NN'),
#   ('materials', 'NNS'),
#   ('to', 'TO'),
#   ('students', 'NNS'),
#   ('who', 'WP'),
#   ('are', 'VBP'),
#   ('still', 'RB'),
#   ('suffering', 'VBG'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('aftermath', 'NN'),
#   ('of', 'IN'),
#   ('KeralaFloods.twitter.com/ao1GASuIut', 'NNP')],
#  [('Local', 'JJ'),
#   ('self-government', 'JJ'),
#   ('institutions', 'NNS'),
#   ('and', 'CC'),
#   ('government', 'NN'),
#   ('departments', 'NNS'),
#   ('are', 'VBP'),
#   ('exercising', 'VBG'),
#   ('extreme', 'JJ'),
#   ('caution', 'NN'),
#   ('to', 'TO'),
#   ('deal', 'VB'),
#   ('with', 'IN'),
#   ('possible', 'JJ'),
#   ('monsoon-related', 'JJ'),
#   ('emergency', 'NN'),
#   ('in', 'IN'),
#   ('Wayanad', 'NNP'),
#   ('after', 'IN'),
#   ('the', 'DT'),
#   ('KeralaFloods', 'NNP'),
#   ('.', '.')],
#  [('Govt', 'NNP'),
#   ('to', 'TO'),
#   ('construct', 'VB'),
#   ('four', 'CD'),
#   ('new', 'JJ'),
#   ('dams', 'NNS'),
#   ('in', 'IN'),
#   ('Kerala', 'NNP'),
#   (';', ':'),
#   ('aims', 'VBZ'),
#   ('to', 'TO'),
#   ('tackle', 'VB'),
#   ('floods', 'NNS'),
#   ('Read', 'NNP'),
#   ('More', 'JJR'),
#   ('-', ':'),
#   ('kerala', 'NN'),
#   ('keralafloods', 'NNS'),
#   ('To', 'TO'),
#   ('Know', 'NNP'),
#   ('More', 'NNP'),
#   ('StateNews', 'NNP'),
#   ('and', 'CC'),
#   ('CurrentUpdates', 'NNP'),
#   ('Download', 'NNP'),
#   ('JustOutNews', 'NNP'),
#   ('App', 'NNP'),
#   ('-', ':'),
#   ('pic.twitter.com/qhbOb7GNsf', 'NN')],
#  [('Thubten', 'NNP'),
#   ('Chodron', 'NNP'),
#   ('speaks', 'VBZ'),
#   ('against', 'IN'),
#   ('Dagri', 'NNP'),
#   ('Rinpoche', 'NNP'),
#   ('.', '.'),
#   ('Watch', 'NNP'),
#   ('AwardWapsiExposed', 'VBD'),
#   ('SonOfTadipar', 'NNP'),
#   ('instagood', 'NN'),
#   ('love', 'NN'),
#   ('FridayFeeling', 'NNP'),
#   ('photography', 'NN'),
#   ('TripleTalaqBill', 'NNP'),
#   ('DarubaazKejri', 'NNP'),
#   ('kolkata', 'VBD'),
#   ('Vishwaroopam', 'NNP'),
#   ('2', 'CD'),
#   ('KeralaFloods', 'NNP'),
#   ('life', 'NN'),
#   ('travel', 'NN'),
#   ('travelphotography', 'NN'),
#   ('ChaloKolkatapic.twitter.com/UlxRbLJUHQ', 'NNP')],
#  [('Chairperson', 'NNP'),
#   ('Ms', 'NNP'),
#   ('.', '.'),
#   ('T.K.Sathi', 'NNP'),
#   ('along', 'IN'),
#   ('with', 'IN'),
#   ('Ward', 'NNP'),
#   ('Counsellor', 'NNP'),
#   ('Mr', 'NNP'),
#   ('.', '.'),
#   ('Shah', 'NNP'),
#   ('of', 'IN'),
#   ('Pandhalam', 'NNP'),
#   ('Municipality', 'NNP'),
#   ('and', 'CC'),
#   ('â', 'NNP'),
#   ('\x81', 'NNP'),
#   ('¦', 'NNP'),
#   ('\x81', 'NNP'),
#   ('©', 'NNP'),
#   ('Kerala', 'NNP'),
#   ('team', 'NN'),
#   ('today', 'NN'),
#   ('inaugurated', 'VBD'),
#   ('the', 'DT'),
#   ('construction', 'NN'),
#   ('work', 'NN'),
#   ('of', 'IN'),
#   ('anganwadi', 'NN'),
#   ('in', 'IN'),
#   ('Ward', 'NNP'),
#   ('no3', 'NN'),
#   ('.', '.'),
#   ('Thank', 'NNP'),
#   ('you', 'PRP'),
#   ('â', 'VBP'),
#   ('\x81', 'JJ'),
#   ('¦', 'NNP'),
#   ('\x81', 'NNP'),
#   ('©', 'NNP'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('support', 'NN'),
#   ('.', '.'),
#   ('keralafloods', 'NNS'),
#   ('pic.twitter.com/2uJMUVdvqa', 'NN')],
#  [('As', 'IN'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('our', 'PRP$'),
#   ('post-flood', 'NN'),
#   ('rehabilitation', 'NN'),
#   ('work', 'NN'),
#   ('in', 'IN'),
#   ('Kerala', 'NNP'),
#   ('the', 'DT'),
#   ('foundation', 'NN'),
#   ('laid', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('construction', 'NN'),
#   ('of', 'IN'),
#   ('an', 'DT'),
#   ('ICDS', 'NNP'),
#   ('centre', 'NN'),
#   ('with', 'IN'),
#   ('support', 'NN'),
#   ('from', 'IN'),
#   ('Care', 'NNP'),
#   ('Today', 'NNP'),
#   ('in', 'IN'),
#   ('Pandhalam', 'NNP'),
#   ('municipality', 'NN'),
#   ('in', 'IN'),
#   ('Pathanamthitta', 'NNP'),
#   ('district', 'NN'),
#   ('in', 'IN'),
#   ('presence', 'NN'),
#   ('of', 'IN'),
#   ('municipality', 'NN'),
#   ('members', 'NNS'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('community', 'NN'),
#   ('members', 'NNS'),
#   ('.', '.'),
#   ('KeralaFloods', 'NNS'),
#   ('pic.twitter.com/1ItsDLGUpx', 'NN')],
#  [('ActionAid', 'NN'),
#   ('with', 'IN'),
#   ('support', 'NN'),
#   ('of', 'IN'),
#   ('Care', 'NNP'),
#   ('Today', 'NNP'),
#   ('Inaugurating', 'NNP'),
#   ('the', 'DT'),
#   ('construction', 'NN'),
#   ('of', 'IN'),
#   ('an', 'DT'),
#   ('Anganwadi', 'NNP'),
#   ('in', 'IN'),
#   ('Pandhalam', 'NNP'),
#   ('MunicipalityPatinamthittaKerala', 'NNP'),
#   ('today', 'NN'),
#   ('along', 'IN'),
#   ('with', 'IN'),
#   ('Municipality', 'NNP'),
#   ('Chairperson', 'NNP'),
#   ('Ms', 'NNP'),
#   ('TK', 'NNP'),
#   ('Sathi', 'NNP'),
#   (';', ':'),
#   ('Ward', 'NNP'),
#   ('Counsellor', 'NNP'),
#   ('Mr', 'NNP'),
#   ('Shah', 'NNP'),
#   ('&', 'CC'),
#   ('other', 'JJ'),
#   ('community', 'NN'),
#   ('members', 'NNS'),
#   ('.', '.'),
#   ('KeralaFloods', 'NNS'),
#   (';', ':'),
#   ('pic.twitter.com/96UR61T5UI', 'NN')],
#  [('Flood', 'NNP'),
#   ('cess', 'NN'),
#   ('at', 'IN'),
#   ('1', 'CD'),
#   ('%', 'NN'),
#   ('from', 'IN'),
#   ('June', 'NNP'),
#   ('onwards', 'NNS'),
#   ('KeralaFloods', 'NNP')],
#  [('Saving', 'VBG'),
#   ('their', 'PRP$'),
#   ('lives', 'NNS'),
#   ('was', 'VBD'),
#   ('our', 'PRP$'),
#   ('priority', 'NN'),
#   ('.', '.'),
#   ('Now', 'RB'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('our', 'PRP$'),
#   ('duty', 'NN'),
#   ('to', 'TO'),
#   ('help', 'VB'),
#   ('them', 'PRP'),
#   ('rebuild', 'VB'),
#   ('it', 'PRP'),
#   ('.', '.'),
#   ('Contribute', 'NNP'),
#   ('generously', 'RB'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('Chief', 'NNP'),
#   ("Minister's", 'NNP'),
#   ('Distress', 'NNP'),
#   ('Relief', 'NNP'),
#   ('Fund', 'NNP'),
#   ('.', '.'),
#   ('KeralaFloods', 'NNP'),
#   ('KeralaFloodReliefpic.twitter.com/SzriNxzZzR', 'NNP')],
#  [('Hearty', 'NNP'),
#   ('Congratulations', 'NNP'),
#   ('!', '.'),
#   ('!', '.'),
#   ('!', '.'),
#   ('Biji', 'NNP'),
#   ('Thomas', 'NNP'),
#   ('of', 'IN'),
#   ('bags', 'NNS'),
#   ('Kerala', 'NNP'),
#   ('State', 'NNP'),
#   ('Television', 'NNP'),
#   ('award', 'NN'),
#   ('-', ':'),
#   ('Best', 'NNP'),
#   ('Director', 'NNP'),
#   ('(', '('),
#   ('Documentary', 'NNP'),
#   (')', ')'),
#   ('for', 'IN'),
#   ('his', 'PRP$'),
#   ('special', 'JJ'),
#   ('programme', 'NN'),
#   ("'", 'POS'),
#   ('Pralayabaaki', 'NNP'),
#   ("'", 'POS'),
#   ('(', '('),
#   ('the', 'DT'),
#   ('remains', 'NNS'),
#   ('of', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   (')', ')'),
#   ('.', '.'),
#   ('pic.twitter.com/jbQA4pHZWX', 'NN')],
#  [('With', 'IN'),
#   ('monsoon', 'NN'),
#   ('expected', 'VBN'),
#   ('to', 'TO'),
#   ('set', 'VB'),
#   ('in', 'IN'),
#   ('over', 'IN'),
#   ('the', 'DT'),
#   ('state', 'NN'),
#   ('anytime', 'NN'),
#   ('now', 'RB'),
#   ('fear', 'VBP'),
#   ('and', 'CC'),
#   ('uncertainty', 'NN'),
#   ('have', 'VBP'),
#   ('gripped', 'VBN'),
#   ('Kurchermala', 'NNP'),
#   ('and', 'CC'),
#   ('Melmuri', 'NNP'),
#   ('residents', 'NNS'),
#   ('majority', 'NN'),
#   ('of', 'IN'),
#   ('whom', 'WP'),
#   ('are', 'VBP'),
#   ('estate', 'NN'),
#   ('workers', 'NNS'),
#   ('in', 'IN'),
#   ('Wayanad', 'NNP'),
#   ('.', '.'),
#   ('KeralaFloods', 'NNS')],
#  [('With', 'IN'),
#   ('monsoon', 'NN'),
#   ('expected', 'VBN'),
#   ('to', 'TO'),
#   ('hit', 'VB'),
#   ('Kerala', 'NNP'),
#   ('soon', 'RB'),
#   ('the', 'DT'),
#   ('nightmarish', 'JJ'),
#   ('experience', 'NN'),
#   ('of', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('flash', 'NN'),
#   ('before', 'IN'),
#   ('the', 'DT'),
#   ('eyes', 'NNS'),
#   ('of', 'IN'),
#   ('residents', 'NNS'),
#   ('as', 'IN'),
#   ('they', 'PRP'),
#   ('fear', 'VBP'),
#   ('excess', 'JJ'),
#   ('rainfall', 'NN'),
#   ('may', 'MD'),
#   ('cause', 'VB'),
#   ('a', 'DT'),
#   ('flood', 'NN'),
#   ('in', 'IN'),
#   ('Pampa', 'NNP'),
#   ('yet', 'RB'),
#   ('again', 'RB'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('state', 'NN'),
#   ('government', 'NN'),
#   ('of', 'IN'),
#   ('Kerala', 'NNP'),
#   ('has', 'VBZ'),
#   ('issued', 'VBN'),
#   ('orders', 'NNS'),
#   ('stating', 'VBG'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('will', 'MD'),
#   ('levy', 'VB'),
#   ('a', 'DT'),
#   ('1', 'CD'),
#   ('%', 'NN'),
#   ("'", "''"),
#   ('flood', 'NN'),
#   ("'", "''"),
#   ('cess', 'NN'),
#   ('on', 'IN'),
#   ('most', 'JJS'),
#   ('goods', 'NNS'),
#   ('and', 'CC'),
#   ('services', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('state', 'NN'),
#   ('from', 'IN'),
#   ('1', 'CD'),
#   ('June', 'NNP'),
#   ('according', 'VBG'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('notification', 'NN'),
#   ('released', 'VBN'),
#   ('on', 'IN'),
#   ('Saturday', 'NNP'),
#   ('.', '.'),
#   ('KeralaFloods', 'NNP'),
#   ('Read', 'VBD'),
#   ('the', 'DT'),
#   ('full', 'JJ'),
#   ('story', 'NN'),
#   (':', ':'),
#   ('â', 'JJ'),
#   ('\x80', 'NNP'),
#   ('¦', 'NNP'),
#   ('pic.twitter.com/AMahQH19KG', 'NN')],
#  [('keralafloods', 'NNS'),
#   ('happened', 'VBD'),
#   ('and', 'CC'),
#   ('crores', 'NNS'),
#   ('of', 'IN'),
#   ('money', 'NN'),
#   ('were', 'VBD'),
#   ('lost', 'VBN'),
#   ('its', 'PRP$'),
#   ('better', 'JJR'),
#   ('to', 'TO'),
#   ('invest', 'VB'),
#   ('the', 'DT'),
#   ('future', 'JJ'),
#   ('money', 'NN'),
#   ('in', 'IN'),
#   ('combating', 'VBG'),
#   ('climatechange', 'NN'),
#   ('â', 'NNP'),
#   ('\x80', 'NNP'),
#   ('¦', 'NN')],
#  [('Thubten', 'NNP'),
#   ('Chodron', 'NNP'),
#   ('speaks', 'VBZ'),
#   ('against', 'IN'),
#   ('Dagri', 'NNP'),
#   ('Rinpoche', 'NNP'),
#   ('.', '.'),
#   ('Watch', 'NNP'),
#   ('AwardWapsiExposed', 'VBD'),
#   ('SonOfTadipar', 'NNP'),
#   ('instagood', 'NN'),
#   ('love', 'NN'),
#   ('FridayFeeling', 'NNP'),
#   ('photography', 'NN'),
#   ('TripleTalaqBill', 'NNP'),
#   ('DarubaazKejri', 'NNP'),
#   ('kolkata', 'VBD'),
#   ('Vishwaroopam', 'NNP'),
#   ('2', 'CD'),
#   ('KeralaFloods', 'NNP'),
#   ('life', 'NN'),
#   ('travel', 'NN'),
#   ('travelphotography', 'NN'),
#   ('ChaloKolkatapic.twitter.com/78VnlPwsOh', 'NNP')],
#  [('@ActionAidIndia', 'NNP'),
#   ('w', 'NN'),
#   ('/', 'NNP'),
#   ('support', 'NN'),
#   ('from', 'IN'),
#   ('inaugurated', 'VBN'),
#   ('the', 'DT'),
#   ('construction', 'NN'),
#   ('of', 'IN'),
#   ('an', 'DT'),
#   ('Anganwadi', 'NNP'),
#   ('today', 'NN'),
#   ('in', 'IN'),
#   ('Pandhalam', 'NNP'),
#   ('MunicipalityPatinamthittaKerala', 'NNP'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('presence', 'NN'),
#   ('of', 'IN'),
#   ('Municipality', 'NNP'),
#   ('Chairperson', 'NNP'),
#   ('Ms', 'NNP'),
#   ('TK', 'NNP'),
#   ('Sathi', 'NNP'),
#   (';', ':'),
#   ('Ward', 'NNP'),
#   ('Counsellor', 'NNP'),
#   ('Mr', 'NNP'),
#   ('Shah', 'NNP'),
#   ('&', 'CC'),
#   ('other', 'JJ'),
#   ('municipality', 'NN'),
#   ('&', 'CC'),
#   ('communi', 'NN')],
#  [('Absolutely', 'RB'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('the', 'DT'),
#   ('ones', 'NNS'),
#   ('who', 'WP'),
#   ('cried', 'VBD'),
#   ('during', 'IN'),
#   ('KeralaFloods', 'NNS'),
#   ('that', 'IN'),
#   ('they', 'PRP'),
#   ('want', 'VBP'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('merged', 'VBN'),
#   ('with', 'IN'),
#   ('UAE', 'NNP'),
#   ('.', '.')],
#  [('Neither', 'CC'),
#   ('did', 'VBD'),
#   ('the', 'DT'),
#   ('Sabarimala', 'NNP'),
#   ('controversy', 'NN'),
#   ('get', 'VBP'),
#   ('the', 'DT'),
#   ('BJP', 'NNP'),
#   ('electoral', 'JJ'),
#   ('victory', 'NN'),
#   ('in', 'IN'),
#   ('Kerala', 'NNP'),
#   ('nor', 'CC'),
#   ('did', 'VBD'),
#   ('it', 'PRP'),
#   ('allow', 'VB'),
#   ('Keralites', 'VBZ'),
#   ('to', 'TO'),
#   ('introspect', 'VB'),
#   ('and', 'CC'),
#   ('learn', 'VB'),
#   ('from', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('.', '.'),
#   ('â', 'VB'),
#   ('\x80', 'JJ'),
#   ('¦', 'NN')],
#  [('The', 'DT'),
#   ('people', 'NNS'),
#   ('of', 'IN'),
#   ('Kerala', 'NNP'),
#   ('missed', 'VBD'),
#   ('an', 'DT'),
#   ('opportunity', 'NN'),
#   ('to', 'TO'),
#   ('introspect', 'VB'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('floods', 'NNS'),
#   ('of', 'IN'),
#   ('August', 'NNP'),
#   ('2018', 'CD'),
#   ('when', 'WRB'),
#   ('the', 'DT'),
#   ('Sabarimala', 'NNP'),
#   ('temple', 'NN'),
#   ('controversy', 'NN'),
#   ('erupted', 'VBD'),
#   ('a', 'DT'),
#   ('month', 'NN'),
#   ('after', 'IN'),
#   ('the', 'DT'),
#   ('extreme', 'JJ'),
#   ('weather', 'NN'),
#   ('event', 'NN'),
#   ('.', '.'),
#   ('â', 'CC'),
#   ('\x80', 'JJ'),
#   ('¦', 'NNP'),
#   ('KeralaFloods', 'NNP'),
#   ('Sabarimala', 'NNP'),
#   ('Commentarypic.twitter.com/3XyoHHTDqz', 'NNP')],
#  [('Not', 'RB'),
#   ('just', 'RB'),
#   ('in', 'IN'),
#   ('Mumbai', 'NNP'),
#   ('but', 'CC'),
#   ('also', 'RB'),
#   ('in', 'IN'),
#   ('many', 'JJ'),
#   ('other', 'JJ'),
#   ('parts', 'NNS'),
#   ('of', 'IN'),
#   ('India', 'NNP'),
#   ('is', 'VBZ'),
#   ('affected', 'VBN'),
#   ('by', 'IN'),
#   ('abnormal', 'JJ'),
#   ('weather', 'NN'),
#   ('conditions', 'NNS'),
#   ('KeralaFloods', 'NNP'),
#   ('chennaifloods', 'NNS'),
#   ('CycloneFani', 'NNP'),
#   ('and', 'CC'),
#   ('many', 'JJ'),
#   ('others', 'NNS'),
#   ('recently', 'RB')],
#  [('And', 'CC'),
#   ('networks', 'NNS'),
#   ('gave', 'VBD'),
#   ('up', 'RP'),
#   ('during', 'IN'),
#   ('fanicyclone', 'NN'),
#   ('n', 'VBP'),
#   ('their', 'PRP$'),
#   ('double', 'JJ'),
#   ('standards', 'NNS'),
#   ('they', 'PRP'),
#   ('gave', 'VBD'),
#   ('free', 'JJ'),
#   ('calls', 'NNS'),
#   ('n', 'JJ'),
#   ('internet', 'NN'),
#   ('during', 'IN'),
#   ('keralafloods', 'NNS'),
#   ('but', 'CC'),
#   ('no', 'DT'),
#   ('such', 'JJ'),
#   ('gesture', 'NN'),
#   ('4', 'CD'),
#   ('Odisha', 'NNP'),
#   ('.', '.'),
#   ('fastest', 'JJS'),
#   ('2', 'CD'),
#   ('restore', 'NN'),
#   ('service', 'NN'),
#   ('...', ':'),
#   ('time', 'NN'),
#   ('2', 'CD'),
#   ('port', 'NN')],
#  [('Aluva', 'NNP'),
#   ('temple', 'NN'),
#   ('authorities', 'NNS'),
#   ('are', 'VBP'),
#   ('focusing', 'VBG'),
#   ('more', 'RBR'),
#   ('on', 'IN'),
#   ('strengthening', 'VBG'),
#   ('the', 'DT'),
#   ('safety', 'NN'),
#   ('measures', 'VBZ'),
#   ('to', 'TO'),
#   ('avert', 'VB'),
#   ('the', 'DT'),
#   ('possibility', 'NN'),
#   ('of', 'IN'),
#   ('natural', 'JJ'),
#   ('calamities', 'NNS'),
#   ('inflicting', 'VBG'),
#   ('damage', 'NN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('temple', 'NN'),
#   ('structure', 'NN'),
#   ('again', 'RB'),
#   ('post', 'VBD'),
#   ('the', 'DT'),
#   ('KeralaFloods', 'NNP'),
#   ('.', '.')],
#  [('Thubten', 'NNP'),
#   ('Chodron', 'NNP'),
#   ('speaks', 'VBZ'),
#   ('against', 'IN'),
#   ('Dagri', 'NNP'),
#   ('Rinpoche', 'NNP'),
#   ('.', '.'),
#   ('Watch', 'NNP'),
#   ('AwardWapsiExposed', 'VBD'),
#   ('SonOfTadipar', 'NNP'),
#   ('instagood', 'NN'),
#   ('love', 'NN'),
#   ('FridayFeeling', 'NNP'),
#   ('photography', 'NN'),
#   ('TripleTalaqBill', 'NNP'),
#   ('DarubaazKejri', 'NNP'),
#   ('kolkata', 'VBD'),
#   ('Vishwaroopam', 'NNP'),
#   ('2', 'CD'),
#   ('KeralaFloods', 'NNP'),
#   ('life', 'NN'),
#   ('travel', 'NN'),
#   ('travelphotography', 'NN'),
#   ('ChaloKolkatapic.twitter.com/8ANdosrsyg', 'NNP')],
#  [('Kerala', 'NNP'),
#   ('defers', 'NNS'),
#   ('flood', 'VBD'),
#   ('cess', 'NN'),
#   ('to', 'TO'),
#   ('July', 'NNP'),
#   ('1', 'CD'),
#   ('to', 'TO'),
#   ('avoid', 'VB'),
#   ('double', 'JJ'),
#   ('taxation', 'NN'),
#   ('KeralaFloods', 'NNS')],
#  [('Criminal', 'JJ'),
#   ('Defamation', 'NNP'),
#   ('case', 'NN'),
#   ('filed', 'VBN'),
#   ('against', 'IN'),
#   ('in', 'IN'),
#   ('HC', 'NNP'),
#   ('Kerala', 'NNP'),
#   ('?', '.'),
#   ('He', 'PRP'),
#   ('allegedly', 'RB'),
#   ('called', 'VBD'),
#   ('them', 'PRP'),
#   ('"', 'NNP'),
#   ('shameless', 'NN'),
#   ('people', 'NNS'),
#   ('"', 'VBP'),
#   ('during', 'IN'),
#   ('a', 'DT'),
#   ('debate', 'NN'),
#   ('regarding', 'VBG'),
#   ('UAE', 'JJ'),
#   ('government', 'NN'),
#   ('providing', 'VBG'),
#   ('flood', 'NN'),
#   ('relief', 'NN'),
#   ('funds', 'NNS'),
#   ('.', '.'),
#   ('KeralaFloods', 'NNS')],
#  [('First', 'NNP'),
#   ('you', 'PRP'),
#   ('help', 'VBP'),
#   ('them', 'PRP'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('hour', 'NN'),
#   ('of', 'IN'),
#   ('crisis', 'NN'),
#   ('...', ':'),
#   ('then', 'RB'),
#   ('they', 'PRP'),
#   ('wil', 'VBP'),
#   ('kill', 'VB'),
#   ('you', 'PRP'),
#   ('when', 'WRB'),
#   ('the', 'DT'),
#   ('time', 'NN'),
#   ('changes', 'NNS'),
#   ('..', 'VBP'),
#   ('keralafloods', 'NNS'),
#   ('pseudoliteracy', 'NN'),
#   ('communals', 'NNS')],
#  [('Interview', 'NN'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('GP2019', 'NNP'),
#   ('team', 'NN'),
#   ('in', 'IN'),
#   ('Geneva', 'NNP'),
#   ('about', 'IN'),
#   ('Chekutty', 'NNP'),
#   ('dolls', 'NNS'),
#   ('and', 'CC'),
#   ('ResilientCommunities', 'NNP'),
#   ('SendaiFramework', 'NNP'),
#   ('KeralaFloods', 'NNP')],
#  [('To', 'TO'),
#   ('deal', 'VB'),
#   ('with', 'IN'),
#   ('future', 'JJ'),
#   ('events', 'NNS'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('necessary', 'JJ'),
#   ('to', 'TO'),
#   ('understand', 'VB'),
#   ('analyse', 'NN'),
#   ('and', 'CC'),
#   ('introspect', 'NN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('past', 'JJ'),
#   ('events', 'NNS'),
#   ('.', '.'),
#   ('â', 'VB'),
#   ('\x80', 'JJ'),
#   ('¦', 'NNP'),
#   ('commentary', 'NN'),
#   ('keralafloods', 'NNS'),
#   ('sabarimala', 'VBP'),
#   ('EnvironmentAndElections', 'NNS'),
#   ('FloodAndDrought', 'NNP')],
#  [('Societies', 'NNS'),
#   ('need', 'VBP'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('through', 'IN'),
#   ('a', 'DT'),
#   ('truth', 'NN'),
#   ('and', 'CC'),
#   ('reconciliation', 'NN'),
#   ('after', 'IN'),
#   ('major', 'JJ'),
#   ('natural', 'JJ'),
#   ('disasters', 'NNS'),
#   ('.', '.'),
#   ('That', 'WDT'),
#   ('will', 'MD'),
#   ('strengthen', 'VB'),
#   ('preparedness', 'NN'),
#   ('for', 'IN'),
#   ('future', 'JJ'),
#   ('events', 'NNS'),
#   ('and', 'CC'),
#   ('strengthen', 'VB'),
#   ('climate', 'NN'),
#   ('resilience', 'NN'),
#   ('.', '.'),
#   ('Sabarimala', 'NNP'),
#   ('Keralafloods', 'NNP'),
#   ('-', ':'),
#   ('â', 'NN'),
#   ('\x80', 'NN'),
#   ('¦', 'NN')],
#  [('Eleksyon', 'NN'),
#   ('2019', 'CD'),
#   ('how', 'WRB'),
#   ('did', 'VBD'),
#   ('get', 'VB'),
#   ('it', 'PRP'),
#   ('right', 'RB'),
#   ('in', 'IN'),
#   ('all', 'DT'),
#   ('states', 'NNS'),
#   ('except', 'IN'),
#   ('Kerala', 'NNP'),
#   ('13', 'CD'),
#   ('NDA', 'NNP'),
#   ('candidates', 'NNS'),
#   ('in', 'IN'),
#   ('Kerala', 'NNP'),
#   ('loses', 'VBZ'),
#   ('security', 'NN'),
#   ('deposit', 'NN'),
#   ('in', 'IN'),
#   ('LS', 'NNP'),
#   ('polls', 'NNS'),
#   ('KeralaFloods', 'NNS')],
#  [('@optumebuilders', 'NNS'),
#   ('Optume', 'VBP'),
#   ('Houselifting', 'VBG'),
#   ('Company', 'NNP'),
#   ('Kochi', 'NNP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('front', 'JJ'),
#   ('runner', 'NN'),
#   ('of', 'IN'),
#   ('house', 'NN'),
#   ('lifting', 'VBG'),
#   ('companies', 'NNS'),
#   ('in', 'IN'),
#   ('Kerala', 'NNP'),
#   ('and', 'CC'),
#   ('are', 'VBP'),
#   ('the', 'DT'),
#   ('pioneers', 'NNS'),
#   ('of', 'IN'),
#   ('this', 'DT'),
#   ('technology', 'NN'),
#   ('.', '.'),
#   ('Home', 'NNP'),
#   ('lifting', 'NN'),
#   ('services', 'NNS'),
#   ('with', 'IN'),
#   ('100', 'CD'),
#   ('%', 'NN'),
#   ('safety', 'NN')],
#  [('Lama', 'NNP'),
#   ('Zopa', 'NNP'),
#   ('&', 'CC'),
#   ('FPMT', 'NNP'),
#   ('promoted', 'VBD'),
#   ('/', 'RB'),
#   ('protected', 'VBN'),
#   ('this', 'DT'),
#   ('Dagri', 'NNP'),
#   ('Rinpoche', 'NNP'),
#   ('.', '.'),
#   ('Woman', 'NNP'),
#   ('on', 'IN'),
#   ('video', 'NN'),
#   ('bravely', 'RB'),
#   ('speaks', 'VBZ'),
#   ('out', 'RP'),
#   ('about', 'IN'),
#   ('her', 'PRP$'),
#   ('molestation', 'NN'),
#   ('by', 'IN'),
#   ('Dagri', 'NNP'),
#   ('Rinpoche', 'NNP'),
#   ('.', '.'),
#   ('Shame', 'NN'),
#   ('!', '.'),
#   ('Why', 'WRB'),
#   ('is', 'VBZ'),
#   ('FPMT', 'NNP'),
#   ('silent', 'NN'),
#   ('?', '.'),
#   ('Vishwaroopam', 'NNP'),
#   ('2', 'CD'),
#   ('KeralaFloods', 'NNP'),
#   ('life', 'NN'),
#   ('travel', 'NN'),
#   ('travelphotography', 'NN'),
#   ('ChaloKolkatapic.twitter.com/Es6ISwZtmz', 'NNP')],
#  [('Thubten', 'NNP'),
#   ('Chodron', 'NNP'),
#   ('speaks', 'VBZ'),
#   ('against', 'IN'),
#   ('Dagri', 'NNP'),
#   ('Rinpoche', 'NNP'),
#   ('.', '.'),
#   ('Watch', 'NNP'),
#   ('AwardWapsiExposed', 'VBD'),
#   ('SonOfTadipar', 'NNP'),
#   ('instagood', 'NN'),
#   ('love', 'NN'),
#   ('FridayFeeling', 'NNP'),
#   ('photography', 'NN'),
#   ('TripleTalaqBill', 'NNP'),
#   ('DarubaazKejri', 'NNP'),
#   ('kolkata', 'VBD'),
#   ('Vishwaroopam', 'NNP'),
#   ('2', 'CD'),
#   ('KeralaFloods', 'NNP'),
#   ('life', 'NN'),
#   ('travel', 'NN'),
#   ('travelphotography', 'NN'),
#   ('ChaloKolkatapic.twitter.com/Xbcpl5gu9y', 'NNP')],
#  [('KeralaFloods', 'NNS'),
#   ('The', 'DT'),
#   ('has', 'VBZ'),
#   ('permitted', 'VBN'),
#   ('the', 'DT'),
#   ('Kerala', 'NNP'),
#   ('government', 'NN'),
#   ('to', 'TO'),
#   ('use', 'VB'),
#   ('the', 'DT'),
#   ('tax', 'NN'),
#   ('to', 'TO'),
#   ('raise', 'VB'),
#   ('funds', 'NNS'),
#   ('to', 'TO'),
#   ('rebuild', 'VB'),
#   ('the', 'DT'),
#   ('state', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('devastation', 'NN'),
#   ('wreaked', 'VBN'),
#   ('by', 'IN'),
#   ('last', 'JJ'),
#   ('yearâ', 'JJ'),
#   ('\x80', 'NNP'),
#   ('\x99', 'NNP'),
#   ('s', 'VBD'),
#   ('floods', 'NNS'),
#   ('.', '.'),
#   ('â', 'VB'),
#   ('\x80', 'JJ'),
#   ('¦', 'NN')],
#  [('Relentless', 'NN'),
#   ('efforts', 'NNS'),
#   ('by', 'IN'),
#   ('volunteers', 'NNS'),
#   ('for', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('victims', 'NNS'),
#   ('have', 'VBP'),
#   ('been', 'VBN'),
#   ('incredible', 'JJ'),
#   ('yet', 'RB'),
#   ('just', 'RB'),
#   ('a', 'DT'),
#   ('drop', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('ocean', 'NN'),
#   ('.', '.'),
#   ('Western', 'JJ'),
#   ('Ghats', 'NNPS'),
#   ('the', 'DT'),
#   ('lifelines', 'NNS'),
#   ('of', 'IN'),
#   ('Indian', 'JJ'),
#   ('Peninsular', 'NNP'),
#   ('must', 'MD'),
#   ('be', 'VB'),
#   ('preserved', 'VBN'),
#   ('to', 'TO'),
#   ('avert', 'VB'),
#   ('such', 'JJ'),
#   ('disasters', 'NNS'),
#   ('for', 'IN'),
#   ('future', 'JJ'),
#   ('generations', 'NNS'),
#   ('.', '.'),
#   ('â', 'VB'),
#   ('\x80', 'JJ'),
#   ('\x93', 'NNP'),
#   ('Sg', 'NNP'),
#   ('pic.twitter.com/UMVtO1kGCS', 'NN')],
#  [('Dear', 'NNP'),
#   ('Kerala', 'NNP'),
#   ('when', 'WRB'),
#   ('our', 'PRP$'),
#   ('state', 'NN'),
#   ('was', 'VBD'),
#   ('battling', 'VBG'),
#   ('the', 'DT'),
#   ('KeralaFloods', 'NNP'),
#   ('Odisha', 'NNP'),
#   ('had', 'VBD'),
#   ('sent', 'VBN'),
#   ('244', 'CD'),
#   ('fire', 'NN'),
#   ('service', 'NN'),
#   ('personnel', 'NNS'),
#   ('and', 'CC'),
#   ('65', 'CD'),
#   ('rescue', 'NN'),
#   ('boats', 'NNS'),
#   ('to', 'TO'),
#   ('help', 'VB'),
#   ('in', 'IN'),
#   ('KeralaFloodrelief', 'NNP'),
#   ('other', 'JJ'),
#   ('than', 'IN'),
#   ('dovating', 'VBG'),
#   ('Rs', 'NNP'),
#   ('10', 'CD'),
#   ('cr', 'NN'),
#   ('.', '.'),
#   ('Now', 'RB'),
#   ('as', 'IN'),
#   ('OdishaFightsBackFani', 'NNP'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('our', 'PRP$'),
#   ('turn', 'NN'),
#   ('to', 'TO'),
#   ('support', 'VB'),
#   ('them', 'PRP'),
#   ('.', '.'),
#   ('CycloneFani', 'NNP'),
#   ('CycloneFaniAftermathpic.twitter.com/lSY9u3qerS', 'NNP')],
#  [('Compare', 'NNP'),
#   ('to', 'TO'),
#   ('complete', 'VB'),
#   ('and', 'CC'),
#   ('malign', 'VB'),
#   ('incompetence', 'NN'),
#   ('exhibited', 'VBN'),
#   ('by', 'IN'),
#   ('kerala', 'NNS'),
#   ('in', 'IN'),
#   ('two', 'CD'),
#   ('cases', 'NNS'),
#   ('in', 'IN'),
#   ('2018', 'CD'),
#   (':', ':'),
#   ('1', 'CD'),
#   ('.', '.'),
#   ('Cyclone', 'NNP'),
#   ('okchi', 'VBD'),
#   ('2', 'CD'),
#   ('.', '.'),
#   ('keralafloods', 'NNS'),
#   ('.', '.'),
#   ('Wild', 'NNP'),
#   ('guess', 'NN'),
#   ('as', 'IN'),
#   ('to', 'TO'),
#   ('why', 'WRB'),
#   ('?', '.'),
#   ('â', 'NN'),
#   ('\x80', 'NN'),
#   ('¦', 'NN')],
#  [('Do', 'VBP'),
#   ('not', 'RB'),
#   ('forget', 'VB'),
#   ('the', 'DT'),
#   ('hatred', 'JJ'),
#   ('BJP', 'NNP'),
#   ('spewed', 'VBD'),
#   ('during', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('and', 'CC'),
#   ('Sabarimala', 'NNP'),
#   ('.', '.'),
#   ('Do', 'NNP'),
#   ('not', 'RB'),
#   ('forget', 'VB'),
#   ('the', 'DT'),
#   ('PM', 'NNP'),
#   ('who', 'WP'),
#   ('never', 'RB'),
#   ('faced', 'VBD'),
#   ('the', 'DT'),
#   ('press', 'NN'),
#   ('.', '.'),
#   ('Do', 'VBP'),
#   ('not', 'RB'),
#   ('forget', 'VB'),
#   ('the', 'DT'),
#   ('Sangh', 'NNP'),
#   ('who', 'WP'),
#   ('wants', 'VBZ'),
#   ('to', 'TO'),
#   ('ruin', 'VB'),
#   ('the', 'DT'),
#   ('secular', 'JJ'),
#   ('fabric', 'NN'),
#   ('of', 'IN'),
#   ('this', 'DT'),
#   ('country', 'NN'),
#   ('VoteOutHate', 'NNP'),
#   ('VoteForLDF', 'NNP'),
#   ('(', '('),
#   ('Also', 'RB'),
#   ("don't", 'VBP'),
#   ('let', 'VB'),
#   ('anyone', 'NN'),
#   ('else', 'RB'),
#   ('decide', 'VB'),
#   ('what', 'WP'),
#   ('we', 'PRP'),
#   ('should', 'MD'),
#   ('eat', 'VB'),
#   (')', ')'),
#   ('pic.twitter.com/CjzbWOEgiN', 'NN')],
#  [('Terrible', 'JJ'),
#   ('lapses', 'NNS'),
#   ('in', 'IN'),
#   ('dam', 'JJ'),
#   ('management', 'NN'),
#   ('was', 'VBD'),
#   ('what', 'WP'),
#   ('gave', 'VBD'),
#   ('way', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('disaster', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('century', 'NN'),
#   ('in', 'IN'),
#   ('Kerala', 'NNP'),
#   ("state's", 'JJ'),
#   ('history', 'NN'),
#   ('.', '.'),
#   ('CM', 'NNP'),
#   ('&', 'CC'),
#   ('all', 'DT'),
#   ('concerned', 'JJ'),
#   ('authorities', 'NNS'),
#   ('must', 'MD'),
#   ('be', 'VB'),
#   ('held', 'VBN'),
#   ('responsible', 'JJ'),
#   ('.', '.'),
#   ('Video', 'NN'),
#   (':', ':'),
#   ('KeralaFloods', 'NNS'),
#   ('Truth', 'VBP')],
#  [('"', 'JJ'),
#   ('Dams', 'NNP'),
#   ('opened', 'VBD'),
#   ('without', 'IN'),
#   ('warning', 'VBG'),
#   ('was', 'VBD'),
#   ('what', 'WP'),
#   ('caused', 'VBD'),
#   ('the', 'DT'),
#   ('2018', 'CD'),
#   ('floods', 'NNS'),
#   ('as', 'IN'),
#   ('per', 'IN'),
#   ('Amicus', 'NNP'),
#   ('Curiae', 'NNP'),
#   ('.', '.'),
#   ('"', 'VB'),
#   ('"', 'JJ'),
#   ('Kerala', 'NNP'),
#   ('CM', 'NNP'),
#   ('should', 'MD'),
#   ('take', 'VB'),
#   ('responsibility', 'NN'),
#   ('&', 'CC'),
#   ('resign', 'NN'),
#   ('.', '.'),
#   ('"', 'CC'),
#   ('"', 'JJ'),
#   ('Kerala', 'NNP'),
#   ('Govt', 'NNP'),
#   ('.', '.'),
#   ('simply', 'RB'),
#   ("can't", 'JJ'),
#   ('run', 'NN'),
#   ('&', 'CC'),
#   ('hide', 'NN'),
#   ('from', 'IN'),
#   ('this', 'DT'),
#   ('.', '.'),
#   ('They', 'PRP'),
#   ('must', 'MD'),
#   ('answer', 'VB'),
#   ('the', 'DT'),
#   ('people', 'NNS'),
#   ('.', '.'),
#   ('"', 'JJ'),
#   ('KeralaFloods', 'NNP'),
#   ('BJPpic.twitter.com/mRxdnw5Kx7', 'NNP')],
#  [('The', 'DT'),
#   ('UDF', 'NNP'),
#   ('has', 'VBZ'),
#   ('been', 'VBN'),
#   ('proved', 'VBN'),
#   ('right', 'RB'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('Amicus', 'NNP'),
#   ('curie', 'NN'),
#   ('report', 'NN'),
#   ('submitted', 'VBD'),
#   ('before', 'IN'),
#   ('the', 'DT'),
#   ('Kerala', 'NNP'),
#   ('High', 'NNP'),
#   ('Court', 'NNP'),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('Kerala', 'NNP'),
#   ('floods', 'NNS'),
#   ('that', 'WDT'),
#   ('took', 'VBD'),
#   ('the', 'DT'),
#   ('lives', 'NNS'),
#   ('of', 'IN'),
#   ('450', 'CD'),
#   ('fellow', 'JJ'),
#   ('mates', 'NNS'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('man', 'NN'),
#   ('made', 'VBN'),
#   ('dam', 'JJ'),
#   ('disaster', 'NN'),
#   ('.', '.'),
#   ('(', '('),
#   ('1/2', 'CD'),
#   (')', ')'),
#   ('KeralaFloods', 'NNP'),
#   ('ManMadeDisaster', 'NNP'),
#   ('LDFGovtPrimeCulprit', 'NNP')],
#  [('Kerala', 'NNP'),
#   ('HC', 'NNP'),
#   ('appointed', 'VBD'),
#   ('Amicus', 'NNP'),
#   ('Curiae', 'NNP'),
#   ('tells', 'VBZ'),
#   ('HC', 'NNP'),
#   ('that', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('2018', 'CD'),
#   ('was', 'VBD'),
#   ('man-made', 'NN'),
#   ('and', 'CC'),
#   ('caused', 'VBN'),
#   ('by', 'IN'),
#   ('mismanagement', 'NN'),
#   ('of', 'IN'),
#   ('dam', 'NN'),
#   ('shutters', 'NNS'),
#   ('(', '('),
#   ('and', 'CC'),
#   ('their', 'PRP$'),
#   ('openings', 'NNS'),
#   (')', ')'),
#   ('.', '.'),
#   ('Calls', 'NNP'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('Judicial', 'JJ'),
#   ('investigation', 'NN'),
#   ('.', '.'),
#   ('Massive', 'JJ'),
#   ('failure', 'NN'),
#   ('of', 'IN'),
#   ('govt', 'NN'),
#   ('.', '.'),
#   ('now', 'RB'),
#   ('officially', 'RB'),
#   ('exposed', 'VBN'),
#   ('?', '.'),
#   ('â', 'JJ'),
#   ('\x80', 'NN'),
#   ('¦', 'NN')],
#  [('These', 'DT'),
#   ('RSS', 'NNP'),
#   ('swaysmsevaks', 'NN'),
#   ('laid', 'VBD'),
#   ('down', 'RB'),
#   ('their', 'PRP$'),
#   ('lives', 'NNS'),
#   ('while', 'IN'),
#   ('rescuing', 'VBG'),
#   ('People', 'NNS'),
#   ('during', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('an', 'DT'),
#   ('epitome', 'NN'),
#   ('of', 'IN'),
#   ('selfless', 'JJ'),
#   ('service', 'NN'),
#   ('.', '.'),
#   ('pic.twitter.com/FaOqoYoKEX', 'NN')],
#  [('Indian', 'JJ'),
#   ('actor', 'NN'),
#   ('joined', 'VBD'),
#   ('our', 'PRP$'),
#   ('teams', 'NNS'),
#   ('to', 'TO'),
#   ('serve', 'VB'),
#   ('LANGAR', 'NNP'),
#   ('(', '('),
#   ('food', 'NN'),
#   (')', ')'),
#   ('to', 'TO'),
#   ('those', 'DT'),
#   ('affected', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('KeralaFloods', 'NNP'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ('.', '.'),
#   ('Great', 'NNP'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('celebrities', 'NNS'),
#   ('serving', 'VBG'),
#   ('humanity', 'NN'),
#   ('.', '.'),
#   ('Thank', 'NNP'),
#   ('you', 'PRP'),
#   ('Randeep', 'VBP'),
#   ('pic.twitter.com/lL3B5urM2a', 'NNS')],
#  [('My', 'PRP$'),
#   ('letter', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('Nobel', 'NNP'),
#   ('Peace', 'NNP'),
#   ('Prize', 'NNP'),
#   ('Committee', 'NNP'),
#   ('nominating', 'VBG'),
#   ('the', 'DT'),
#   ('fishermen', 'NNS'),
#   ('of', 'IN'),
#   ('Kerala', 'NNP'),
#   ('for', 'IN'),
#   ('this', 'DT'),
#   ("year's", 'JJ'),
#   ('Peace', 'NNP'),
#   ('Prize', 'NNP'),
#   ('in', 'IN'),
#   ('recognition', 'NN'),
#   ('of', 'IN'),
#   ('their', 'PRP$'),
#   ('courageous', 'JJ'),
#   ('service', 'NN'),
#   ('&', 'CC'),
#   ('sacrifice', 'NN'),
#   ('during', 'IN'),
#   ('the', 'DT'),
#   ('KeralaFloods', 'NNP'),
#   ('of', 'IN'),
#   ('2018', 'CD'),
#   (':', ':'),
#   ('pic.twitter.com/xtPLrTnQBT', 'NN')],
#  [('*', 'NN'),
#   ('Excluded', 'VBD'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('list', 'NN'),
#   ('of', 'IN'),
#   ('states', 'NNS'),
#   ('eligible', 'JJ'),
#   ('for', 'IN'),
#   ('central', 'JJ'),
#   ('disaster', 'NN'),
#   ('funds', 'NNS'),
#   ('*', 'VBP'),
#   ('Blocked', 'NNP'),
#   ('generous', 'JJ'),
#   ('aid', 'NN'),
#   ('from', 'IN'),
#   ('foreign', 'JJ'),
#   ('countries', 'NNS'),
#   ('*', 'VBP'),
#   ('Tried', 'VBN'),
#   ('to', 'TO'),
#   ('thwart', 'VB'),
#   ('our', 'PRP$'),
#   ('fundraising', 'VBG'),
#   ('through', 'IN'),
#   ('IT', 'NNP'),
#   ('cell', 'NN'),
#   ('audio', 'VBZ'),
#   ('clips', 'NNS'),
#   ('*', 'RB'),
#   ('Now', 'RB'),
#   ('they', 'PRP'),
#   ('send', 'VBP'),
#   ('us', 'PRP'),
#   ('a', 'DT'),
#   ('bill', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('IAF', 'NNP'),
#   ('for', 'IN'),
#   ('flood', 'NN'),
#   ('rescue', 'NN'),
#   ('KeralaFloods', 'NNS')],
#  [('OMG', 'NN'),
#   ('!', '.'),
#   ('!', '.'),
#   ('We', 'PRP'),
#   ('Kerala', 'VBP'),
#   ("didn't", 'JJ'),
#   ('welcome', 'NN'),
#   ('like', 'IN'),
#   ('this', 'DT'),
#   ('even', 'RB'),
#   ('though', 'IN'),
#   ('he', 'PRP'),
#   ("didn't", 'VBZ'),
#   ('provide', 'VB'),
#   ('fund', 'NN'),
#   ('for', 'IN'),
#   ('Keralafloods', 'NNP'),
#   ('and', 'CC'),
#   ('called', 'VBD'),
#   ('us', 'PRP'),
#   ('Somalians', 'NNPS'),
#   ('!', '.'),
#   ('!', '.'),
#   ('GoBackModipic.twitter.com/QT93FqI5nZ', 'NN')],
#  [('My', 'PRP$'),
#   ('intervention', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('Lok', 'NNP'),
#   ('Sabha', 'NNP'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('CycloneOckhi', 'NNP'),
#   ('Rehabilitation', 'NNP'),
#   ('Package', 'NN'),
#   (':', ':'),
#   ('central', 'JJ'),
#   ('Govt', 'NNP'),
#   ('gave', 'VBD'),
#   ('only', 'RB'),
#   ('â', 'JJ'),
#   ('\x82', 'VBD'),
#   ('¹118cr', 'CD'),
#   ('against', 'IN'),
#   ('State', 'NNP'),
#   ('Govt', 'NNP'),
#   ('requirement', 'NN'),
#   ('of', 'IN'),
#   ('â', 'NNP'),
#   ('\x82', 'NNP'),
#   ('¹7304', 'CD'),
#   ('cr', 'NN'),
#   ('(', '('),
#   ('\x80', 'JJ'),
#   ('\x99', 'NNP'),
#   ('s', 'NN'),
#   ('figures', 'NNS'),
#   ('are', 'VBP'),
#   ('wrong', 'JJ'),
#   ('â', 'JJ'),
#   ('\x80', 'NN'),
#   ('\x94', 'NN'),
#   ('he', 'PRP'),
#   ('must', 'MD'),
#   ('have', 'VB'),
#   ('been', 'VBN'),
#   ('thinking', 'VBG'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Keralafloods', 'NNP'),
#   (')', ')'),
#   ('â', 'VBP'),
#   ('\x80', 'JJ'),
#   ('¦', 'NN')],
#  [('We', 'PRP'),
#   ('are', 'VBP'),
#   ('STILL', 'NNP'),
#   ('in', 'IN'),
#   ('Kerala', 'NNP'),
#   ('after', 'IN'),
#   ('the', 'DT'),
#   ('floods', 'NNS'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ('!', '.'),
#   ('We', 'PRP'),
#   ('donâ', 'VBP'),
#   ('\x80', 'JJ'),
#   ('\x99', 'NNP'),
#   ('t', 'NN'),
#   ('walk', 'NN'),
#   ('away', 'RB'),
#   ('few', 'JJ'),
#   ('days', 'NNS'),
#   ('after', 'IN'),
#   ('the', 'DT'),
#   ('disaster', 'NN'),
#   ('...', ':'),
#   ('We', 'PRP'),
#   ('remain', 'VBP'),
#   ('committed', 'JJ'),
#   ('.', '.'),
#   ('Kerala', 'NNP'),
#   ('KeralaFloods', 'NNP'),
#   ('pic.twitter.com/Ly5f45SNAV', 'NN')],
#  [('Spoke', 'NNP'),
#   ('strongly', 'RB'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('RGIDS', 'NNP'),
#   ('conclave', 'NN'),
#   ('in', 'IN'),
#   ('Thiruvananthapuram', 'NNP'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('KeralaFloods', 'NNP'),
#   ('&', 'CC'),
#   ('the', 'DT'),
#   ('way', 'NN'),
#   ('forward', 'RB'),
#   ('.', '.'),
#   ('Urged', 'VBD'),
#   ('the', 'DT'),
#   ('state', 'NN'),
#   ('to', 'TO'),
#   ('follow', 'VB'),
#   ('the', 'DT'),
#   ('Gujarat', 'NNP'),
#   ('model', 'NN'),
#   ('of', 'IN'),
#   ('2001', 'CD'),
#   ('&', 'CC'),
#   ('hold', 'VB'),
#   ('an', 'DT'),
#   ('International', 'NNP'),
#   ('Donor', 'NNP'),
#   ('Conference', 'NNP'),
#   ('to', 'TO'),
#   ('RebuildKerala', 'NNP'),
#   ('Better', 'NNP'),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('solidarity', 'NN'),
#   ('shown', 'VBN'),
#   ('during', 'IN'),
#   ('the', 'DT'),
#   ('floods', 'NNS'),
#   ('needs', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('revived', 'VBN'),
#   ('.', '.'),
#   ('pic.twitter.com/rCN6H8u70S', 'NN')],
#  [('Have', 'VBP'),
#   ('been', 'VBN'),
#   ('speaking', 'VBG'),
#   ('to', 'TO'),
#   ('Sanjay', 'NNP'),
#   ('Kirloskar', 'NNP'),
#   ('chief', 'NN'),
#   ('of', 'IN'),
#   ('about', 'IN'),
#   ('helping', 'VBG'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('crisis', 'NN'),
#   ('in', 'IN'),
#   ('Meghalaya', 'NNP'),
#   ('.', '.'),
#   ('He', 'PRP'),
#   ('has', 'VBZ'),
#   ('rushed', 'VBN'),
#   ('a', 'DT'),
#   ('team', 'NN'),
#   ('to', 'TO'),
#   ('assess', 'VB'),
#   ('the', 'DT'),
#   ('actual', 'JJ'),
#   ('needs', 'NNS'),
#   (':', ':'),
#   ('what', 'WP'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('pumps', 'NNS'),
#   ('would', 'MD'),
#   ('best', 'VB'),
#   ('work', 'NN'),
#   ('in', 'IN'),
#   ('local', 'JJ'),
#   ('conditions', 'NNS'),
#   ('.', '.'),
#   ('Meanwhile', 'RB'),
#   ('his', 'PRP$'),
#   ('pumps', 'NNS'),
#   ('used', 'VBN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('KeralaFloods', 'NNP'),
#   ('cld', 'NN'),
#   ('be', 'VB'),
#   ('diverted', 'VBN'),
#   ('if', 'IN'),
#   ('suitable', 'JJ')],
#  [('Attended', 'NNP'),
#   ('three', 'CD'),
#   ('different', 'JJ'),
#   ('Christmas', 'NNP'),
#   ('celebrations', 'NNS'),
#   ('at', 'IN'),
#   ('churches', 'NNS'),
#   ('in', 'IN'),
#   ('rural', 'JJ'),
#   ('Amaravila', 'NNP'),
#   ('.', '.'),
#   ('Spoke', 'NNP'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('real', 'JJ'),
#   ('message', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('birth', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Son', 'NNP'),
#   ('ofGod', 'NN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('manger', 'NN'),
#   (':', ':'),
#   ('our', 'PRP$'),
#   ('duty', 'NN'),
#   ('today', 'NN'),
#   ('to', 'TO'),
#   ('think', 'VB'),
#   ('of', 'IN'),
#   ('those', 'DT'),
#   ('who', 'WP'),
#   ('have', 'VBP'),
#   ('nothing', 'NN'),
#   ('not', 'RB'),
#   ('even', 'RB'),
#   ('a', 'DT'),
#   ('home', 'NN'),
#   ('.', '.'),
#   ('True', 'NNP'),
#   ('Xmas', 'NNP'),
#   ('spirit', 'NN'),
#   (':', ':'),
#   ('the', 'DT'),
#   ('solidarity', 'NN'),
#   ('that', 'WDT'),
#   ('marked', 'VBD'),
#   ('the', 'DT'),
#   ('KeralaFloods', 'NNP'),
#   ('.', '.'),
#   ('pic.twitter.com/4vwj7I0acq', 'NN')],
#  [('KeralaFloods', 'NNP'),
#   ('-', ':'),
#   ('total', 'JJ'),
#   ('loss', 'NN'),
#   ('31000', 'CD'),
#   ('crores', 'NNS'),
#   ('.', '.'),
#   ('Aid', 'NNP'),
#   ('given', 'VBN'),
#   ('by', 'IN'),
#   ('Centre', 'NNP'),
#   ('-', ':'),
#   ('600', 'CD'),
#   ('crore', 'NN'),
#   ('.', '.'),
#   ('GajaCyclone', 'NNP'),
#   ('-', ':'),
#   ('Tamilnadu', 'NN'),
#   ('requires', 'VBZ'),
#   ('relief', 'JJ'),
#   ('worth', 'JJ'),
#   ('15000', 'CD'),
#   ('crores.Amount', 'NN'),
#   ('given', 'VBN'),
#   ('by', 'IN'),
#   ('Centre', 'NNP'),
#   ('?', '.'),
#   ('Only', 'RB'),
#   ('353', 'CD'),
#   ('crore', 'NN'),
#   ('.', '.'),
#   ('Why', 'WRB'),
#   ('is', 'VBZ'),
#   ('South', 'NNP'),
#   ('India', 'NNP'),
#   ('treated', 'VBD'),
#   ('so', 'RB'),
#   ('unjustly', 'RB'),
#   ('?', '.'),
#   ('Cause', 'NNP'),
#   ('we', 'PRP'),
#   ("don't", 'VBP'),
#   ('fall', 'VB'),
#   ('for', 'IN'),
#   ("BJP's", 'NNP'),
#   ('mandir', 'NN'),
#   ('politics', 'NNS'),
#   ('and', 'CC'),
#   ('vote', 'NN'),
#   ('for', 'IN'),
#   ('them', 'PRP'),
#   ('?', '.')],
#  [('After', 'IN'),
#   ('giving', 'VBG'),
#   ('a', 'DT'),
#   ('miserly', 'JJ'),
#   ('500', 'CD'),
#   ('crores', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('devastating', 'VBG'),
#   ('KeralaFloods', 'NNP'),
#   ('Relief', 'NNP'),
#   ('now', 'RB'),
#   ('the', 'DT'),
#   ('Modi', 'NNP'),
#   ('Govt', 'NNP'),
#   ('is', 'VBZ'),
#   ('asking', 'VBG'),
#   ('290', 'CD'),
#   ('crores', 'NNS'),
#   ('back', 'RB'),
#   ('.', '.'),
#   ('This', 'DT'),
#   ('after', 'IN'),
#   ('they', 'PRP'),
#   ('blocked', 'VBD'),
#   ('Foreign', 'NNP'),
#   ("Govt's", 'NNP'),
#   ('from', 'IN'),
#   ('contributing', 'VBG'),
#   ('.', '.'),
#   ('Modi', 'NNP'),
#   ("Govt's", 'NNP'),
#   ('mean', 'NN'),
#   ('spiritedness', 'NN'),
#   ('is', 'VBZ'),
#   ('shocking', 'VBG'),
#   ('&', 'CC'),
#   ('shameful', 'JJ'),
#   ('!', '.'),
#   ('â', 'JJ'),
#   ('\x80', 'NN'),
#   ('¦', 'NN')],
#  [('Damage', 'NN'),
#   ('from', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('-', ':'),
#   ('â', 'NN'),
#   ('\x82', 'VBZ'),
#   ('¹31000', 'CD'),
#   ('crore', 'NN'),
#   ('Aid', 'NNP'),
#   ('requested', 'VBN'),
#   ('by', 'IN'),
#   ('Kerala', 'NNP'),
#   ('-', ':'),
#   ('â', 'NN'),
#   ('\x82', 'VBZ'),
#   ('¹2000', 'CD'),
#   ('crore', 'NN'),
#   ('Aid', 'NNP'),
#   ('given', 'VBN'),
#   ('by', 'IN'),
#   ('Centre', 'NNP'),
#   ('-', ':'),
#   ('â', 'NN'),
#   ('\x82', 'NN'),
#   ('¹600', 'CD'),
#   ('crore', 'NN'),
#   ('Bill', 'NNP'),
#   ('sent', 'VBN'),
#   ('by', 'IN'),
#   ('Centre', 'NNP'),
#   ('to', 'TO'),
#   ('Kerala', 'NNP'),
#   ('govt', 'NN'),
#   ('for', 'IN'),
#   ('food', 'NN'),
#   ('and', 'CC'),
#   ('emergency', 'NN'),
#   ('rescue', 'NN'),
#   ('work', 'NN'),
#   ('during', 'IN'),
#   ('floods', 'NNS'),
#   ('-', ':'),
#   ('â', 'NN'),
#   ('\x82', 'NN'),
#   ('¹290', 'CD'),
#   ('crore', 'NN'),
#   ('Waah', 'NNP'),
#   ('Modiji', 'NNP'),
#   ('waah.Let', 'NN'),
#   ("'", "''"),
#   ('s', 'JJ'),
#   ('build', 'NN'),
#   ('another', 'DT'),
#   ('statue', 'NN'),
#   ('though', 'IN'),
#   ('of', 'IN'),
#   ('course', 'NN'),
#   ('!', '.'),
#   ('pic.twitter.com/RtwZKuPqPH', 'NN')],
#  [('Centre', 'NNP'),
#   ('has', 'VBZ'),
#   ('demaded', 'VBN'),
#   ('Rs', 'NNP'),
#   ('.', '.'),
#   ('290.67', 'CD'),
#   ('crs', 'NN'),
#   ('from', 'IN'),
#   ('Kerala', 'NNP'),
#   ('govt', 'NN'),
#   ('.', '.'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('relief', 'NN'),
#   ('aid', 'NN'),
#   ('provided', 'VBN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('time', 'NN'),
#   ('of', 'IN'),
#   ('keralafloods', 'NNS'),
#   ('.', '.'),
#   ('This', 'DT'),
#   ('includes', 'VBZ'),
#   ('25cr', 'CD'),
#   ('for', 'IN'),
#   ('rescue', 'NN'),
#   ('helicopters', 'NNS'),
#   ('&', 'CC'),
#   ('food', 'NN'),
#   ('during', 'IN'),
#   ('floods', 'NNS'),
#   ('-', ':'),
#   ('in', 'IN'),
#   ('Legislative', 'NNP'),
#   ('assembly', 'NN'),
#   ('Unbelievable', 'JJ'),
#   ('!', '.'),
#   ('pic.twitter.com/mCly1v3BPc', 'NN')],
#  [('Heroes', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('year', 'NN'),
#   ('-', ':'),
#   ('Indian', 'JJ'),
#   ('Navy', 'NNP'),
#   ('Commander', 'NNP'),
#   ('Vijay', 'NNP'),
#   ('Varma', 'NNP'),
#   ('and', 'CC'),
#   ('Captain', 'NNP'),
#   ('P', 'NNP'),
#   ('Rajkumar', 'NNP'),
#   ('were', 'VBD'),
#   ('awarded', 'VBN'),
#   ("'", 'POS'),
#   ('Asian', 'NNP'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Year', 'NNP'),
#   ("'", 'POS'),
#   ('for', 'IN'),
#   ('their', 'PRP$'),
#   ('selfless', 'NN'),
#   ('service', 'NN'),
#   ('&', 'CC'),
#   ('bravery', 'NN'),
#   ('in', 'IN'),
#   ('rescue', 'NN'),
#   ('operations', 'NNS'),
#   ('during', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('.', '.'),
#   ('pic.twitter.com/SBpq3gAMz6', 'NN')],
#  [('Was', 'NNP'),
#   ('happy', 'JJ'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('this', 'DT'),
#   ('photo', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('EB', 'NNP'),
#   ('team', 'NN'),
#   ('sent', 'VBD'),
#   ('from', 'IN'),
#   ('Wayanad', 'NNP'),
#   ('Kerala', 'NNP'),
#   ('and', 'CC'),
#   ('mobilised', 'VBN'),
#   ('by', 'IN'),
#   ('IAS', 'NNP'),
#   ('.', '.'),
#   ('TN', 'NNP'),
#   ('sending', 'VBG'),
#   ('relief', 'NN'),
#   ('trucks', 'NNS'),
#   ('during', 'IN'),
#   ('KeralaFloods', 'NNS'),
#   ('and', 'CC'),
#   ('Kerala', 'NNP'),
#   ('sending', 'VBG'),
#   ('help', 'NN'),
#   ('during', 'IN'),
#   ('the', 'DT'),
#   ('GajaCyclone', 'NNP'),
#   ('makes', 'VBZ'),
#   ('my', 'PRP$'),
#   ('belief', 'JJ'),
#   ('firm', 'NN'),
#   ('on', 'IN'),
#   ('these', 'DT'),
#   ('words', 'NNS'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('banner', 'NN'),
#   ('in', 'IN'),
#   ('this', 'DT'),
#   ('pic', 'NN'),
#   ('-', ':'),
#   ('Oru', 'NNP'),
#   ('Desam', 'NNP'),
#   ('Oru', 'NNP'),
#   ('makkal.pic.twitter.com/olqBvbpofl', 'NN')],
#  [('You', 'PRP'),
#   ('can', 'MD'),
#   ('now', 'RB'),
#   ('shop', 'VB'),
#   ('from', 'IN'),
#   ('our', 'PRP$'),
#   ('original', 'JJ'),
#   ('wardrobe', 'NN'),
#   ('of', 'IN'),
#   ('aiyaary', 'JJ'),
#   ('and', 'CC'),
#   ('your', 'PRP$'),
#   ('purchase', 'NN'),
#   ('will', 'MD'),
#   ('support', 'VB'),
#   ('continuing', 'VBG'),
#   ('relief', 'JJ'),
#   ('work', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('KeralaFloods', 'NNP'),
#   ('!', '.'),
#   ('Humbled', 'VBD'),
#   ('that', 'IN'),
#   ('my', 'PRP$'),
#   ('movie', 'NN'),
#   ('closet', 'NN'),
#   ('can', 'MD'),
#   ('serve', 'VB'),
#   ('this', 'DT'),
#   ('importantâ', 'NN'),
#   ('\x80', 'VBZ'),
#   ('¦', 'NNP'),
#   ('â', 'NNP'),
#   ('\x80', 'NNP'),
#   ('¦', 'NN')],
#  [('Thalapathy', 'NNP'),
#   ('has', 'VBZ'),
#   ('deposited', 'VBN'),
#   ('various', 'JJ'),
#   ('amounts', 'NNS'),
#   ('ranging', 'VBG'),
#   ('from', 'IN'),
#   ('â', 'NNP'),
#   ('\x82', 'NNP'),
#   ('¹', 'CD'),
#   ('2', 'CD'),
#   ('Laksh', 'NNP'),
#   ('to', 'TO'),
#   ('â', 'VB'),
#   ('\x82', 'JJ'),
#   ('¹', 'CD'),
#   ('4.50', 'CD'),
#   ('Lakhs', 'NN'),
#   ('to', 'TO'),
#   ('his', 'PRP$'),
#   ('Fan', 'NNP'),
#   ('club', 'NN'),
#   ('heads', 'NNS'),
#   ('bank', 'NN'),
#   ('accounts', 'NNS'),
#   ('in', 'IN'),
#   ('CycloneGaja', 'NNP'),
#   ('affected', 'VBD'),
#   ('areas', 'NNS'),
#   ('to', 'TO'),
#   ('help', 'VB'),
#   ('the', 'DT'),
#   ('needy', 'NN'),
#   ('..', 'VBD'),
#   ('Similar', 'NNP'),
#   ('to', 'TO'),
#   ('what', 'WP'),
#   ('he', 'PRP'),
#   ('did', 'VBD'),
#   ('during', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('Kudos', 'NNP'),
#   ('to', 'TO'),
#   ('his', 'PRP$'),
#   ('generous', 'JJ'),
#   ('gesture', 'NN'),
#   ('!', '.'),
#   ('pic.twitter.com/Qhy1EO57E6', 'NN')],
#  [('ThalapathyVijay', 'NNP'),
#   ('has', 'VBZ'),
#   ('deposited', 'VBN'),
#   ('Rs', 'NNP'),
#   ('2', 'CD'),
#   ('lakhs', 'NN'),
#   ('to', 'TO'),
#   ('4.5', 'CD'),
#   ('lakhs', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('bank', 'NN'),
#   ('accounts', 'NNS'),
#   ('of', 'IN'),
#   ('his', 'PRP$'),
#   ('fan', 'NN'),
#   ('club', 'NN'),
#   ('heads', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('GajaCyclone', 'NNP'),
#   ('affected', 'VBD'),
#   ('areas', 'NNS'),
#   ('.', '.'),
#   ('Fans', 'NNS'),
#   ('will', 'MD'),
#   ('take', 'VB'),
#   ('care', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('relief', 'NN'),
#   ('measures', 'NNS'),
#   ('and', 'CC'),
#   ('help', 'VB'),
#   ('needy', 'JJ'),
#   ('people', 'NNS'),
#   ('.', '.'),
#   ('He', 'PRP'),
#   ('followed', 'VBD'),
#   ('similar', 'JJ'),
#   ('method', 'NN'),
#   ('during', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('.', '.'),
#   ('pic.twitter.com/q23VqSyy8Y', 'NN')],
#  [('Satellite', 'NNP'),
#   ('images', 'VBZ'),
#   ('show', 'VBP'),
#   ('that', 'IN'),
#   ('most', 'JJS'),
#   ('lakes', 'NNS'),
#   ('/', 'VBP'),
#   ('dams', 'NNS'),
#   ('in', 'IN'),
#   ('North', 'NNP'),
#   ('TN', 'NNP'),
#   ('are', 'VBP'),
#   ('either', 'DT'),
#   ('empty', 'JJ'),
#   ('or', 'CC'),
#   ('having', 'VBG'),
#   ('enough', 'JJ'),
#   ('cushion', 'NN'),
#   ('to', 'TO'),
#   ('hold', 'VB'),
#   ('flood', 'NN'),
#   ('waters', 'NNS'),
#   ('.', '.'),
#   ('CycloneGaja', 'NNP'),
#   ('should', 'MD'),
#   ('not', 'RB'),
#   ('be', 'VB'),
#   ('equated', 'VBN'),
#   ('with', 'IN'),
#   ('Keralafloods', 'NNP'),
#   ('.', '.'),
#   ('We', 'PRP'),
#   ('face', 'VBP'),
#   ('other', 'JJ'),
#   ('types', 'NNS'),
#   ('of', 'IN'),
#   ('risks', 'NNS'),
#   ('!', '.'),
#   ('Legend', 'NN'),
#   (':', ':'),
#   ('Red-empty', 'JJ'),
#   ('lake', 'NN'),
#   ('beds', 'NNS'),
#   ('Blue-water', 'NNP'),
#   ('Based', 'VBD'),
#   ('on', 'IN'),
#   ('images', 'NNS'),
#   ('from.twitter.com/kHBAKv9LtW', 'VBP')],
#  [('When', 'WRB'),
#   ('India', 'NNP'),
#   ('cant', 'NN'),
#   ('take', 'VB'),
#   ('help', 'NN'),
#   ('/', 'VB'),
#   ('funds', 'NNS'),
#   ('from', 'IN'),
#   ('for', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('disaster', 'NN'),
#   ('then', 'RB'),
#   ('how', 'WRB'),
#   ('can', 'MD'),
#   ('we', 'PRP'),
#   ('take', 'VB'),
#   ('donation', 'NN'),
#   ('from', 'IN'),
#   ('Britain', 'NNP'),
#   ('for', 'IN'),
#   ('Statue', 'NNP'),
#   ('Building', 'NNP'),
#   ('?', '.'),
#   ('â', 'NNP'),
#   ('\x80', 'NNP'),
#   ('¦', 'NN')],
#  [('More', 'JJR'),
#   ('than', 'IN'),
#   ('228', 'CD'),
#   ('Libraries', 'NNPS'),
#   ('partially', 'RB'),
#   ('or', 'CC'),
#   ('fully', 'RB'),
#   ('destroyed', 'VBN'),
#   ('in', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('.', '.'),
#   ('Lakhs', 'NNP'),
#   ('of', 'IN'),
#   ('books', 'NNS'),
#   ('lost', 'VBN'),
#   ('.', '.'),
#   ('"', 'CC'),
#   ('One', 'CD'),
#   ('Library', 'NNP'),
#   ('Per', 'NNP'),
#   ('Village', 'NNP'),
#   ('"', 'NNP'),
#   ('campaign', 'NN'),
#   ('by', 'IN'),
#   ('promoters', 'NNS'),
#   ('of', 'IN'),
#   ('BookBucketChallenge', 'NNP'),
#   ('organizing', 'VBG'),
#   ('RebuildLibrary', 'NNP'),
#   ('campaign', 'NN'),
#   ('across', 'IN'),
#   ('Kerala', 'NNP'),
#   (':', ':'),
#   ('&', 'CC')],
#  [('Just', 'RB'),
#   ('bumped', 'VBN'),
#   ('into', 'IN'),
#   ('Capt', 'NNP'),
#   ('P', 'NNP'),
#   ('.', '.'),
#   ('Rajkumar', 'NNP'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('â', 'NNP'),
#   ('\x80', 'NNP'),
#   ('\x94', 'VBD'),
#   ('the', 'DT'),
#   ('hero', 'NN'),
#   ('Sea', 'NNP'),
#   ('King', 'NNP'),
#   ('pilot', 'NN'),
#   ('who', 'WP'),
#   ('created', 'VBD'),
#   ('a', 'DT'),
#   ('new', 'JJ'),
#   ('record', 'NN'),
#   ('during', 'IN'),
#   ('the', 'DT'),
#   ('KeralaFloods', 'NNP'),
#   ('rescuing', 'VBG'),
#   ('26', 'CD'),
#   ('people', 'NNS'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('single', 'JJ'),
#   ('helicopter', 'NN'),
#   ('sortie', 'NN'),
#   ('.', '.'),
#   ('Rockstar', 'NNP'),
#   ('aviator', 'NN'),
#   ('.', '.'),
#   ('pic.twitter.com/Bynlfk5Eyl', 'NN')],
#  [('Kerala', 'NNP'),
#   ('Top', 'NNP'),
#   ('Opening', 'NNP'),
#   ('Weekend', 'NNP'),
#   ('Grossers', 'NNP'),
#   ('-', ':'),
#   ('(', '('),
#   ('Direct', 'JJ'),
#   ('Telugu', 'NNP'),
#   ('Movies', 'NNP'),
#   (')', ')'),
#   ('AravindhaSametha', 'NNP'),
#   ('-', ':'),
#   ('â', 'NN'),
#   ('\x82', 'VBZ'),
#   ('¹5', 'CD'),
#   ('.', '.'),
#   ('62L', 'CD'),
#   ('(', '('),
#   ('4', 'CD'),
#   ('Days', 'NNPS'),
#   (')', ')'),
#   ('BharatAneNenu', 'NNP'),
#   ('-', ':'),
#   ('â', 'NN'),
#   ('\x82', 'VBZ'),
#   ('¹5', 'CD'),
#   ('.', '.'),
#   ('51L', 'CD'),
#   ('(', '('),
#   ('3', 'CD'),
#   ('Days', 'NNPS'),
#   (')', ')'),
#   ('GeethaGovindam', 'NNP'),
#   ('-', ':'),
#   ('â', 'NN'),
#   ('\x82', 'VBZ'),
#   ('¹5L', 'CD'),
#   ('(', '('),
#   ('5', 'CD'),
#   ('Days', 'NNPS'),
#   (')', ')'),
#   ('-', ':'),
#   ('*', 'NN'),
#   ('KeralaFloods', 'NNP'),
#   ('Peak', 'NNP'),
#   ('Time', 'NNP'),
#   ('Katamarayudu', 'NNP'),
#   ('-', ':'),
#   ('â', 'NN'),
#   ('\x82', 'VBZ'),
#   ('¹4', 'CD'),
#   ('.', '.'),
#   ('8L', 'CD'),
#   ('(', '('),
#   ('3', 'CD'),
#   ('Days', 'NNPS'),
#   (')', ')'),
#   ('.twitter.com/dLFuvH28Nw', 'VBP')],
#  [('Srikakulam', 'NNP'),
#   ('District', 'NNP'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('state', 'NN'),
#   ('of', 'IN'),
#   ('AndhraPradesh', 'NNP'),
#   ('is', 'VBZ'),
#   ('badly', 'RB'),
#   ('effected', 'VBN'),
#   ('due', 'JJ'),
#   ('to', 'TO'),
#   ('CycloneTitli', 'NNP'),
#   ('.', '.'),
#   ("Can't", 'NNP'),
#   ('we', 'PRP'),
#   ('create', 'VBP'),
#   ('an', 'DT'),
#   ('Payment', 'NNP'),
#   ('channel', 'NN'),
#   ('in', 'IN'),
#   ('for', 'IN'),
#   ('Cyclone', 'NNP'),
#   ('Titli', 'NNP'),
#   ('Relief', 'NNP'),
#   ('Fund', 'NNP'),
#   ('.', '.'),
#   ('We', 'PRP'),
#   ('are', 'VBP'),
#   ('requesting', 'VBG'),
#   ('to', 'TO'),
#   ('help', 'VB'),
#   ('the', 'DT'),
#   ('needy', 'NN'),
#   ('as', 'IN'),
#   ('like', 'IN'),
#   ('in', 'IN'),
#   ('KeralaFloods..twitter.com/vq8IeEV2xK', 'NNP')],
#  [('This', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('appreciation', 'NN'),
#   ('tweet', 'NN'),
#   ('.', '.'),
#   ('I', 'PRP'),
#   ('am', 'VBP'),
#   ('thrown', 'JJ'),
#   ('by', 'IN'),
#   ('her', 'PRP$'),
#   ('relentless', 'JJ'),
#   ('hard', 'JJ'),
#   ('workâ', 'NN'),
#   ('\x80', 'NNP'),
#   ('\x94', 'NNP'),
#   ('right', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('KeralaFloods', 'NNP'),
#   ('to', 'TO'),
#   ('MeToo', 'NNP'),
#   ('now', 'RB'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('equanimity', 'NN'),
#   ('and', 'CC'),
#   ('compassion', 'NN'),
#   ('that', 'IN'),
#   ('shape', 'VBZ'),
#   ('her', 'PRP$'),
#   ('leadership', 'NN'),
#   ('.', '.')],
#  [('Heroes', 'NNS'),
#   ('warriors', 'NNS'),
#   ('or', 'CC'),
#   ('champions', 'NNS'),
#   (';', ':'),
#   ('call', 'VB'),
#   ('them', 'PRP'),
#   ('what', 'WP'),
#   ('you', 'PRP'),
#   ('want', 'VBP'),
#   ('.', '.'),
#   ('Tomorrow', 'VB'),
#   ('we', 'PRP'),
#   ('salute', 'VB'),
#   ('them', 'PRP'),
#   ('and', 'CC'),
#   ('we', 'PRP'),
#   ('play', 'VBP'),
#   ('for', 'IN'),
#   ('them', 'PRP'),
#   ('.', '.'),
#   ('Kudos', 'VB'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('management', 'NN'),
#   ('for', 'IN'),
#   ('showing', 'VBG'),
#   ('why', 'WRB'),
#   ('this', 'DT'),
#   ('team', 'NN'),
#   ('is', 'VBZ'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('people', 'NNS'),
#   ('!', '.'),
#   ('KeralaFloods', 'NNP'),
#   ('KERMUM', 'NNP'),
#   ('â', 'NNP'),
#   ('\x80', 'NNP'),
#   ('¦', 'NN')],
#  [('To', 'TO'),
#   ('honor', 'VB'),
#   ('our', 'PRP$'),
#   ('saviors', 'NNS'),
#   ('from', 'IN'),
#   ('during', 'IN'),
#   ('the', 'DT'),
#   ('KeralaFloods', 'NNP'),
#   ('the', 'DT'),
#   ('boys', 'NNS'),
#   ('will', 'MD'),
#   ('be', 'VB'),
# ...
#   ('him', 'PRP'),
#   ('for', 'IN'),
#   ('opening', 'VBG'),
#   ('his', 'PRP$'),
#   ('mouth', 'NN'),
#   ('condemning', 'VBG'),
#   ('the', 'DT'),
#   ('rape', 'NN'),
#   ('of', 'IN'),
#   ('woman', 'NN'),
#   ('by', 'IN'),
#   ('five', 'CD'),
#   ('priests', 'NNS'),
#   ('a', 'DT'),
#   ('nun', 'NN'),
#   ('by', 'IN'),
#   ('a', 'DT'),
#   ('Bishop', 'NNP'),
#   ('from', 'IN'),
#   ('Kerala', 'NNP'),
#   ('.', '.'),
#   ('I', 'PRP'),
#   ('suppose', 'VBP'),
#   ('that', 'IN'),
#   ('not', 'RB'),
#   ('extraordinary', 'JJ'),
#   ('crisis', 'NN'),
#   ('.', '.')],
#  [('Chengannur', 'NNP'),
#   ('needs', 'VBZ'),
#   ('immediate', 'JJ'),
#   ('air-lifting', 'NN'),
#   ('of', 'IN'),
#   ('its', 'PRP$'),
#   ('residents', 'NNS'),
#   ('..', 'VBP'),
#   ('The', 'DT'),
#   ('situation', 'NN'),
#   ('is', 'VBZ'),
#   ('very', 'RB'),
#   ('alarming', 'JJ'),
#   ('..', 'NN'),
#   ('keralafloods', 'NNS'),
#   ('kerala', 'VBP'),
#   ('SaveChengannurpic.twitter.com/l9RuqtEjGR', 'NNP')],
#  [('Kerala', 'NNP'),
#   ('has', 'VBZ'),
#   ('real', 'JJ'),
#   ('leaders', 'NNS'),
#   ('who', 'WP'),
#   ('are', 'VBP'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('ground', 'NN'),
#   ('working', 'VBG'),
#   ('not', 'RB'),
#   ('waving', 'VBG'),
#   ('at', 'IN'),
#   ('people', 'NNS'),
#   ('from', 'IN'),
#   ('airplane', 'NN'),
#   ('!', '.'),
#   ('IndiaForKerala', 'NNP'),
#   ('KeralaFloods', 'NNP'),
#   ('pic.twitter.com/b3CWHt5s2R', 'NN')],
#  [('PM', 'NNP'),
#   ('reaches', 'VBZ'),
#   ('Kerala', 'NNP'),
#   ('to', 'TO'),
#   ('take', 'VB'),
#   ('stock', 'NN'),
#   ('of', 'IN'),
#   ('flood', 'JJ'),
#   ('situation', 'NN'),
#   (';', ':'),
#   ('National', 'NNP'),
#   ('Crisis', 'NNP'),
#   ('Management', 'NNP'),
#   ('Committee', 'NNP'),
#   ('meets', 'NNS'),
#   ('again', 'RB'),
#   (';', ':'),
#   ('NDRF', 'NNP'),
#   ('Army', 'NNP'),
#   ('Navy', 'NNP'),
#   ('Air', 'NNP'),
#   ('Force', 'NNP'),
#   ('and', 'CC'),
#   ('other', 'JJ'),
#   ('agencies', 'NNS'),
#   ('step', 'VBP'),
#   ('up', 'RB'),
#   ('rescue', 'NN'),
#   ('and', 'CC'),
#   ('relief', 'JJ'),
#   ('operations', 'NNS'),
#   ('KeralaFloods', 'NNS'),
#   ('pic.twitter.com/eiNw7lvfPr', 'NN')],
#  [('WATCH', 'NN'),
#   (':', ':'),
#   ('Aerial', 'JJ'),
#   ('visual', 'NN'),
#   ('of', 'IN'),
#   ('flooded', 'JJ'),
#   ('Kalady', 'NNP'),
#   ('as', 'IN'),
#   ('rain', 'NN'),
#   ('continues', 'VBZ'),
#   ('to', 'TO'),
#   ('lash', 'VB'),
#   ('the', 'DT'),
#   ('state', 'NN'),
#   ('.', '.'),
#   ('KeralaFloods', 'NNP'),
#   ('(', '('),
#   ('17.08', 'CD'),
#   ('.', '.'),
#   ('18', 'CD'),
#   (')', ')'),
#   ('pic.twitter.com/lhu4oR50H7', 'NN')],
#  [('PM', 'NNP'),
#   ('walked', 'VBD'),
#   ('the', 'DT'),
#   ('entire', 'JJ'),
#   ('route', 'NN'),
#   ('of', 'IN'),
#   ("ABV's", 'NNP'),
#   ('funeral', 'JJ'),
#   ('procession', 'NN'),
#   (':', ':'),
#   ('hours', 'NNS'),
#   ('later', 'RB'),
#   ('he', 'PRP'),
#   ('is', 'VBZ'),
#   ('in', 'IN'),
#   ('Kerala', 'NNP'),
#   ('.', '.'),
#   ('Meanwhile', 'RB'),
#   ('State', 'NNP'),
#   ('politicians', 'NNS'),
#   ('tasked', 'VBD'),
#   ('with', 'IN'),
#   ('flood', 'NN'),
#   ('relief', 'NN'),
#   ('in', 'IN'),
#   ('Kottayam', 'NNP'),
#   ('district', 'NN'),
#   ('K', 'NNP'),
#   ('Raju', 'NNP'),
#   ('of', 'IN'),
#   ('Communist', 'NNP'),
#   ('Party', 'NNP'),
#   ('and', 'CC'),
#   ('Muslim', 'NNP'),
#   ('League', 'NNP'),
#   ('MP', 'NNP'),
#   ('Mohammed', 'NNP'),
#   ('Basheer', 'NNP'),
#   ('are', 'VBP'),
#   ('on', 'IN'),
#   ('junket', 'NN'),
#   ('in', 'IN'),
#   ('Germany', 'NNP'),
#   ('.', '.'),
#   ('KeralaFloods', 'NNP'),
#   ('pic.twitter.com/bBHgWFYtaZ', 'NN')],
#  [('KeralaFloods', 'NNS'),
#   ('KeralaFloodRelief', 'NNP'),
#   ('Please', 'NNP'),
#   ('send', 'VB'),
#   ('only', 'RB'),
#   ('new', 'JJ'),
#   ('items', 'NNS'),
#   ('.', '.'),
#   ('Used', 'VBN'),
#   ('will', 'MD'),
#   ('not', 'RB'),
#   ('be', 'VB'),
#   ('accepted', 'VBN'),
#   ('.', '.'),
#   ('Neighbouring', 'VBG'),
#   ('Wayanad', 'NNP'),
#   ('has', 'VBZ'),
#   ('added', 'VBN'),
#   ('8000', 'CD'),
#   ('+', 'NNP'),
#   ('new', 'JJ'),
#   ('residents', 'NNS'),
#   ('in', 'IN'),
#   ('camps', 'NNS'),
#   ('over', 'IN'),
#   ('the', 'DT'),
#   ('past', 'JJ'),
#   ('few', 'JJ'),
#   ('days', 'NNS'),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('following', 'JJ'),
#   ('list', 'NN'),
#   ('has', 'VBZ'),
#   ('been', 'VBN'),
#   ('made', 'VBN'),
#   ('in', 'IN'),
#   ('consultation', 'NN'),
#   ('with', 'IN'),
#   ('Wayanad', 'NNP'),
#   ('Admin', 'NNP'),
#   ('.', '.'),
#   ('List', 'NN'),
#   ('is', 'VBZ'),
#   ('in', 'IN'),
#   ('order', 'NN'),
#   ('of', 'IN'),
#   ('priority', 'NN'),
#   ('-pic.twitter.com/1VZQsbkdtf', 'NN')],
#  [('Around', 'IN'),
#   ('700', 'CD'),
#   ('soldiers', 'NNS'),
#   ('along', 'IN'),
#   ('with', 'IN'),
#   ('specialised', 'JJ'),
#   ('engineering', 'NN'),
#   ('task', 'NN'),
#   ('forces', 'NNS'),
#   ('carrying', 'VBG'),
#   ('boats', 'NNS'),
#   ('&', 'CC'),
#   ('specialised', 'JJ'),
#   ('equipment', 'NN'),
#   ('are', 'VBP'),
#   ('on', 'IN'),
#   ('ground', 'NN'),
#   ('&', 'CC'),
#   ('have', 'VBP'),
#   ('rescued', 'VBN'),
#   ('around', 'IN'),
#   ('4800', 'CD'),
#   ('people', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('past', 'JJ'),
#   ('9', 'CD'),
#   ('days', 'NNS'),
#   ('.', '.'),
#   ('I', 'PRP'),
#   ('assure', 'VBP'),
#   ('that', 'IN'),
#   ("we'll", 'JJ'),
#   ('work', 'NN'),
#   ('day', 'NN'),
#   ('&', 'CC'),
#   ('night', 'NN'),
#   ('till', 'NN'),
#   ('Kerala', 'NNP'),
#   ('comes', 'VBZ'),
#   ('back', 'RB'),
#   ('to', 'TO'),
#   ('normal', 'JJ'),
#   (':', ':'),
#   ('Brig', 'NNP'),
#   ('Arun', 'NNP'),
#   ('CG', 'NNP'),
#   ('KeralaFloods', 'NNP'),
#   ('(', '('),
#   ('17.8', 'CD'),
#   ('.', '.'),
#   ('18', 'CD'),
#   (')', ')'),
#   ('pic.twitter.com/7apVlgIg39', 'NN')],
#  [('Canada', 'NNP'),
#   ('stands', 'VBZ'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('people', 'NNS'),
#   ('of', 'IN'),
#   ('India', 'NNP'),
#   ('who', 'WP'),
#   ('have', 'VBP'),
#   ('lost', 'VBN'),
#   ('loved', 'VBN'),
#   ('ones', 'NNS'),
#   ('and', 'CC'),
#   ('are', 'VBP'),
#   ('affected', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('devastating', 'VBG'),
#   ('monsoon', 'NN'),
#   ('floods', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('Kerala', 'NNP'),
#   ('region', 'NN'),
#   ('the', 'DT'),
#   ('worst', 'JJS'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('century', 'NN'),
#   ('.', '.'),
#   ('KeralaFloods', 'NNS')],
#  [('For', 'IN'),
#   ('all', 'DT'),
#   ('of', 'IN'),
#   ('us', 'PRP'),
#   ('in', 'IN'),
#   ('Mumbai', 'NNP'),
#   ("let's", 'NN'),
#   ('do', 'VB'),
#   ('our', 'PRP$'),
#   ('best', 'JJS'),
#   ('to', 'TO'),
#   ('help', 'VB'),
#   ('others', 'NNS'),
#   ('in', 'IN'),
#   ('need', 'NN'),
#   ('.', '.'),
#   ('Here', 'RB'),
#   ('are', 'VBP'),
#   ('some', 'DT'),
#   ('useful', 'JJ'),
#   ('details', 'NNS'),
#   ('.', '.'),
#   ('Mumbai', 'NNP'),
#   ('KeralaFloods', 'NNP'),
#   ('KeralaSOS', 'NNP'),
#   ('IndiaForKerala', 'NNP'),
#   ('KeralaDonationChallenge', 'NNP'),
#   ('Kerala', 'NNP'),
#   ('KeralaFloodsHelpNeeded', 'NNP'),
#   ('KeralaRescue', 'NNP'),
#   ('KeralaFloodRescuepic.twitter.com/jm8zmT7YOP', 'NNP')],
#  [('Please', 'VB'),
#   ('donate', 'VB'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('are', 'VBP'),
#   ('able', 'JJ'),
#   ('to', 'TO'),
#   ('ARMY', 'NNP'),
#   ('and', 'CC'),
#   ('spread', 'VBD'),
#   ('the', 'DT'),
#   ('word', 'NN'),
#   (':', ':'),
#   ('KeralaFloodRelief', 'NNP'),
#   ('StandWithKerala', 'NNP'),
#   ('KeralaFloods', 'NNP')],
#  [('When', 'WRB'),
#   ('KeralaFloods', 'NNP'),
#   ('subside', 'NN'),
#   ('I', 'PRP'),
#   ('hope', 'VBP'),
#   ('we', 'PRP'),
#   ('will', 'MD'),
#   ('remember', 'VB'),
#   ('one', 'CD'),
#   ('name', 'NN'),
#   (':', ':'),
#   ('gadgil', 'NN'),
#   ('.', '.'),
#   ('His', 'PRP$'),
#   ('report', 'NN'),
#   ('predicted', 'VBD'),
#   ('calamity', 'NN'),
#   ('if', 'IN'),
#   ('western', 'JJ'),
#   ('ghats', 'NNS'),
#   ('were', 'VBD'),
#   ('not', 'RB'),
#   ('protected', 'VBN'),
#   ('.', '.'),
#   ('Of', 'IN'),
#   ('course', 'NN'),
#   ('vested', 'JJ'),
#   ('interests', 'NNS'),
#   ('pooh', 'VBP'),
#   ('poohed', 'VBD'),
#   ('him', 'PRP')],
#  [('After', 'IN'),
#   ('the', 'DT'),
#   ('shameful', 'JJ'),
#   ('neglect', 'NN'),
#   ('of', 'IN'),
#   ('Kerala', 'NNP'),
#   ('regarding', 'VBG'),
#   ('Ockhi', 'NNP'),
#   ('cyclone', 'NN'),
#   ('relief', 'NN'),
#   ('funds', 'NNS'),
#   ('now', 'RB'),
#   ('Modi-led', 'NNP'),
#   ('BJP', 'NNP'),
#   ('government', 'NN'),
#   ('has', 'VBZ'),
#   ('turned', 'VBN'),
#   ('its', 'PRP$'),
#   ('back', 'NN'),
#   ('on', 'IN'),
#   ('Kerala', 'NNP'),
#   ('yet', 'RB'),
#   ('again', 'RB'),
#   ('-', ':'),
#   ('by', 'IN'),
#   ('not', 'RB'),
#   ('sending', 'VBG'),
#   ('enough', 'RB'),
#   ('armed', 'VBN'),
#   ('forces', 'NNS'),
#   ('and', 'CC'),
#   ('by', 'IN'),
#   ('allotting', 'VBG'),
#   ('a', 'DT'),
#   ('paltry', 'NN'),
#   ('Rs', 'NNP'),
#   ('.', '.'),
#   ('100', 'CD'),
#   ('cr', 'NN'),
#   ('for', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('.', '.'),
#   ('PMmustAnswer', 'NNP'),
#   ('â', 'NNP'),
#   ('\x80', 'NNP'),
#   ('¦', 'NN')],
#  [('Same', 'JJ'),
#   ('story', 'NN'),
#   (':', ':'),
#   ('ICAR', 'NNP'),
#   ('UG', 'NNP'),
#   ('entrance', 'NN'),
#   ('exam', 'NN'),
#   ('is', 'VBZ'),
#   ('scheduled', 'VBN'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('held', 'VBN'),
#   ('this', 'DT'),
#   ('Sunday', 'NNP'),
#   ('19th', 'CD'),
#   ('August', 'NNP'),
#   ('.', '.'),
#   ('Because', 'IN'),
#   ('of', 'IN'),
#   ('KeralaFloods', 'NNP'),
#   ('it', 'PRP'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('very', 'RB'),
#   ('difficult', 'JJ'),
#   ('for', 'IN'),
#   ('most', 'JJS'),
#   ('Keralites', 'NNS'),
#   ('to', 'TO'),
#   ('reach', 'VB'),
#   ('exam', 'JJ'),
#   ('centres', 'NNS'),
#   ('.', '.'),
#   ('Could', 'NNP'),
#   ('postpone', 'VBD'),
#   ('the', 'DT'),
#   ('exams', 'NN'),
#   ('or', 'CC'),
#   ('do', 'VB'),
#   ('a', 'DT'),
#   ('repeat', 'NN'),
#   ('exam', 'NN'),
#   ('for', 'IN'),
#   ('affected', 'JJ'),
#   ('Keralites', 'NNP'),
#   ('?', '.'),
#   ('â', 'NNP'),
#   ('\x80', 'NNP'),
#   ('¦', 'NN')],
#  [('A', 'DT'),
#   ('group', 'NN'),
#   ('of', 'IN'),
#   ('enthusiastic', 'JJ'),
#   ('young', 'JJ'),
#   ('people', 'NNS'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('it', 'PRP'),
#   ('easier', 'JJR'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('relief', 'NN'),
#   ('to', 'TO'),
#   ('victims', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('KeralaFloods', 'NNP'),
#   ('pic.twitter.com/v31wWy70Fk', 'NN')],
#  [('Kerala', 'NNP'),
#   ('is', 'VBZ'),
#   ('in', 'IN'),
#   ('dire', 'NN'),
#   ('straits', 'NNS'),
#   ('Help', 'NNP'),
#   ('is', 'VBZ'),
#   ('needed', 'VBN'),
#   ('..', 'JJ'),
#   ('Cmon', 'NNP'),
#   ('insta-fam', 'NN'),
#   ('..', 'NNP'),
#   ('letâ', 'VBZ'),
#   ('\x80', 'NNP'),
#   ('\x99', 'NNP'),
#   ('s', 'VBD'),
#   ('get', 'VB'),
#   ('together', 'RB'),
#   ('and', 'CC'),
#   ('help', 'VB'),
#   ('.', '.'),
#   ('prayforkerala', 'VB'),
#   ('Keralafloods', 'NNP'),
#   ('letsdothistogether', 'CC'),
#   ('prayers', 'NNS'),
#   ('â', 'VBP'),
#   ('\x80', 'CD'),
#   ('¦', 'NN')],
#  [('"', 'JJ'),
#   ('Please', 'NNP'),
#   ('ask', 'VB'),
#   ('Modi', 'NNP'),
#   ('to', 'TO'),
#   ('give', 'VB'),
#   ('us', 'PRP'),
#   ('helicopters', 'NNS'),
#   ('...', ':'),
#   ('please', 'VB'),
#   ('please', 'VB'),
#   ('50000', 'CD'),
#   ('people', 'NNS'),
#   ('will', 'MD'),
#   ('die', 'VB'),
#   ('.', '.'),
#   ('We', 'PRP'),
#   ('were', 'VBD'),
#   ('demanding', 'VBG'),
#   ('for', 'IN'),
#   ('Navy', 'NNP'),
#   ('help', 'NN'),
#   ('for', 'IN'),
#   ('four', 'CD'),
#   ('days', 'NNS'),
#   ('.', '.'),
#   ('Airlifting', 'NNP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('only', 'JJ'),
#   ('solution', 'NN'),
#   ('.', '.'),
#   ('Please', 'NNP'),
#   ('please', 'VB'),
#   ('please', 'VB'),
#   ('"', 'NNP'),
#   ('Chengannur', 'NNP'),
#   ('MLA', 'NNP'),
#   ('Saji', 'NNP'),
#   ('Cherian', 'NNP'),
#   ('broke', 'VBD'),
#   ('down', 'RB'),
#   ('on', 'IN'),
#   ('TV', 'NN'),
#   ('.', '.'),
#   ('KeralaFloods', 'NNS'),
#   ('KeralaFloodsHelpNeeded', 'VBD')],
#  [('Please', 'VB'),
#   ('help', 'VB'),
#   ('us', 'PRP'),
#   ('..', 'IN'),
#   ('we', 'PRP'),
#   ('are', 'VBP'),
#   ('desperately', 'RB'),
#   ('in', 'IN'),
#   ('need', 'NN'),
#   ('of', 'IN'),
#   ('help', 'NN'),
#   ('Armys', 'NNP'),
#   ('..', 'VBZ'),
#   ('the', 'DT'),
#   ('situation', 'NN'),
#   ('here', 'RB'),
#   ('is', 'VBZ'),
#   ('much', 'RB'),
#   ('much', 'JJ'),
#   ('worse', 'JJR'),
#   ('..', 'JJ'),
#   ('PLEASE', 'NNP'),
#   ('.', '.'),
#   ('Chengannur', 'NNP'),
#   ('SaveKerala', 'NNP'),
#   ('KeralaFloods', 'NNP')],
#  [('324', 'CD'),
#   ('people', 'NNS'),
#   ('have', 'VBP'),
#   ('been', 'VBN'),
#   ('killed', 'VBN'),
#   ('in', 'IN'),
#   ('flooding', 'VBG'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('southern', 'JJ'),
#   ('Indian', 'JJ'),
#   ('state', 'NN'),
#   ('of', 'IN'),
#   ('Kerala', 'NNP'),
#   ('.', '.'),
#   ('local', 'JJ'),
#   ('officials', 'NNS'),
#   ('say', 'VBP'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('worst', 'JJS'),
#   ('flooding', 'NN'),
#   ('in', 'IN'),
#   ('100', 'CD'),
#   ('years', 'NNS'),
#   ('.', '.'),
#   ('My', 'PRP$'),
#   ('thoughts', 'NNS'),
#   ('are', 'VBP'),
#   ('with', 'IN'),
#   ('all', 'PDT'),
#   ('those', 'DT'),
#   ('affected', 'VBN'),
#   ('.', '.'),
#   ('KeralaFloods', 'NNS'),
#   ('pic.twitter.com/kXk2jWtU01', 'NN')],
#  [('Even', 'RB'),
#   ('UAE', 'JJ'),
#   ('government', 'NN'),
#   ('are', 'VBP'),
#   ('considering', 'VBG'),
#   ('Kerala', 'NNP'),
#   ('kindly.why', 'NN'),
#   ('did', 'VBD'),
#   ('central', 'JJ'),
#   ('government', 'NN'),
#   ('not', 'RB'),
#   ('delivering', 'VBG'),
#   ('sufficient', 'JJ'),
#   ('aid', 'NN'),
#   ('to', 'TO'),
#   ('Kerala', 'NNP'),
#   ('yet.centre', 'NNP'),
#   ('should', 'MD'),
#   ('provide', 'VB'),
#   ('more', 'JJR'),
#   ('military', 'JJ'),
#   ('services', 'NNS'),
#   ('and', 'CC'),
#   ('announce', 'VB'),
#   ('keralaflood', 'NN'),
#   ('as', 'IN'),
#   ('national', 'JJ'),
#   ('calamity', 'NN'),
#   ('.', '.'),
#   ('IndiaForKerala', 'NNP'),
#   ('PMMustAnswer', 'NNP'),
#   ('chengannur', 'NN'),
#   ('KeralaFloods', 'NNP'),
#   ('pic.twitter.com/XnI3NlqUfu', 'NN')],
#  [('OMG', 'NNP'),
#   ('Big', 'NNP'),
#   ('crisis', 'NN'),
#   ('!', '.'),
#   ('!', '.'),
#   ('MLA', 'NNP'),
#   ('Cherian', 'NNP'),
#   ('said', 'VBD'),
#   ('during', 'IN'),
#   ('a', 'DT'),
#   ('TV', 'NN'),
#   ('show', 'NN'),
#   ('today', 'NN'),
#   ('â', 'NNP'),
#   ('\x80', 'NNP'),
#   ('\x9c', 'NNP'),
#   ('Please', 'NNP'),
#   ('ask', 'VB'),
#   ('to', 'TO'),
#   ('give', 'VB'),
#   ('us', 'PRP'),
#   ('helicopters', 'NNS'),
#   (';', ':'),
#   ('50000', 'CD'),
#   ('people', 'NNS'),
#   ('will', 'MD'),
#   ('die', 'VB'),
#   ('otherwise', 'RB'),
#   ('...', ':'),
#   ('Airlifting', 'NNP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('only', 'JJ'),
#   ('solution', 'NN'),
#   ('.', '.'),
#   ('Please', 'NNP'),
#   ('please', 'VB'),
#   ('pleaseâ', 'JJ'),
#   ('\x80', 'NNP'),
#   ('\x9d', 'NNP'),
#   ('IndiaForKerala', 'NNP'),
#   ('KeralaFloods', 'NNP')],
#  [('The', 'DT'),
#   ('Life', 'NNP'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('Dog', 'NNP'),
#   ('caught', 'NN'),
#   ('in', 'IN'),
#   ('Keralafloods', 'NNP'),
#   ('being', 'VBG'),
#   ('saved', 'VBN'),
#   ('by', 'IN'),
#   ('few', 'JJ'),
#   ('good', 'JJ'),
#   ('souls', 'NNS'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('most', 'RBS'),
#   ('heartening', 'JJ'),
#   ('video', 'NN'),
#   ('you', 'PRP'),
#   ('will', 'MD'),
#   ('see', 'VB'),
#   ('today', 'NN'),
#   ('.', '.'),
#   ('Kudos', 'NNP'),
#   ('KeralaFloods', 'NNP'),
#   ('KeralaSOS', 'NNP'),
#   ('KeralaFloodRelief', 'NNP'),
#   ('IndiaForKerala', 'NNP'),
#   ('IndiaStandsWithKerala', 'NNP'),
#   ('StandforKeralapic.twitter.com/rHemUikWHj', 'NNP')],
#  [('Rescue', 'NNP'),
#   ('operations', 'NNS'),
#   ('are', 'VBP'),
#   ('on', 'IN'),
#   ('its', 'PRP$'),
#   ('last', 'JJ'),
#   ('leg', 'NN'),
#   ('in', 'IN'),
#   ('Kerala.over', 'NNP'),
#   ('3.14', 'CD'),
#   ('lakh', 'NN'),
#   ('people', 'NNS'),
#   ('are', 'VBP'),
#   ('in', 'IN'),
#   ('camps', 'NNS'),
#   ('.', '.'),
#   ('Now', 'RB'),
#   ('the', 'DT'),
#   ('need', 'NN'),
#   ('of', 'IN'),
#   ('hour', 'NN'),
#   ('is', 'VBZ'),
#   ('food', 'NN'),
#   ('&', 'CC'),
#   ('water', 'NN'),
#   ('.', '.'),
#   ('Many', 'JJ'),
#   ('in', 'IN'),
#   ('these', 'DT'),
#   ('camps', 'NNS'),
#   ('are', 'VBP'),
#   ('starving', 'VBG'),
#   ('for', 'IN'),
#   ('3-4', 'JJ'),
#   ('days', 'NNS'),
#   ('.', '.'),
#   ('please', 'VB'),
#   ('contact', 'JJ'),
#   ('HinduHelpline', 'NNP'),
#   ('&', 'CC'),
#   ('donate', 'VB'),
#   ('food', 'NN'),
#   ('&', 'CC'),
#   ('those', 'DT'),
#   ('in', 'IN'),
#   ('camps', 'NNS'),
#   ('who', 'WP'),
#   ('need', 'VBP'),
#   ('food', 'NN'),
#   ('contact', 'NN'),
#   ('9400161516', 'CD'),
#   ('Keralafloods', 'NNP'),
#   ('pic.twitter.com/Poz7AqFQVm', 'NN')],
#  [('More', 'JJR'),
#   ('than', 'IN'),
#   ('500', 'CD'),
#   ('people', 'NNS'),
#   ('were', 'VBD'),
#   ('rescued', 'VBN'),
#   ('by', 'IN'),
#   ('ITBP', 'NNP'),
#   ('personnel', 'NNS'),
#   ('from', 'IN'),
#   ('floodhit', 'JJ'),
#   ('Alleppey', 'NNP'),
#   ('&', 'CC'),
#   ('Pathanamthitta', 'NNP'),
#   ('.', '.'),
#   ('KeralaFloods', 'NNP'),
#   ('(', '('),
#   ('17.08', 'CD'),
#   ('.', '.'),
#   ('18', 'CD'),
#   (')', ')'),
#   ('pic.twitter.com/hpiFmALftU', 'NN')],
#  ...]

# %%
#pattern = 'NP: {<DT>?<JJ>*<NN>}'
#cp = nltk.RegexpParser(pattern)
#cs = cp.parse(nltk_pos[-68])
#print(cs)

# %%
#iob_tagged= tree2conlltags(cs)
#pprint(iob_tagged)

# %% [markdown]
# Now using Stanford Natural Processing!!
# First, we will set the config_java file for nltk

# %%
nltk.internals.config_java("/usr/lib/jvm/java-11-openjdk-amd64/bin/java")
st = StanfordNERTagger('/home/pranav/Desktop/zine/Twitter-Mining/stanford-ner-2018-10-16/classifiers/english.all.3class.distsim.crf.ser.gz',
           '/home/pranav/Desktop/zine/Twitter-Mining/stanford-ner-2018-10-16/stanford-ner.jar', encoding='utf-8')

# %%
#nltk_ents = []
#for tweet in tqdm(nltk_tweets):
#    entity_tagged_tweet = st.tag(tweet)
#    nltk_ents.append([tag for tag in entity_tagged_tweet if tag[1] != 'O'])

# %% [markdown]
# The Standford Named Entity Recognition library labels the text in the tweets, particularly into 3 classes (PERSON, ORGANIZATION, LOCATION).<br>
# As, numerals will also be significant in the tweets we will concatenate it to the entity text. Hence, from the text we will take care about the entities and numbers.<br>
# I will name these array content_tweets

# %% [markdown]
# Again, entities that are labelled as PERSON tend to be related more to feelings of the person, hence I will remove them as well.

# %%
content_tweets = []
for pos_tweet, tweet_entity in zip(nltk_pos, nltk_ents):
    # starting by appending all of the entities
    tweet_content = [word[0] for word in tweet_entity if word[1] != 'PERSON']
    
    # next by appending all of the numerals
    for token in pos_tweet:
         if token[1] == u'CD':
            tweet_content.append(token[0])
    content_tweets.append(tweet_content)
# Out:
# [[],
#  ['Kerala'],
#  ['Wayanad'],
#  ['Kerala', 'four'],
#  ['2'],
#  ['Pandhalam', 'Municipality', 'Kerala', 'Ward'],
#  ['Kerala', 'Care', 'Today', 'Pandhalam', 'Pathanamthitta'],
#  ['ActionAid', 'Pandhalam', 'Municipality', 'Patinamthitta', 'Kerala'],
#  ['1'],
#  [],
#  ['Kerala', 'State', 'Television'],
#  ['Wayanad'],
#  ['Kerala', 'Pampa'],
#  ['Kerala', '1', '1'],
#  [],
#  ['2'],
#  ['Pandhalam', 'Municipality', 'Patinamthitta', 'Kerala'],
#  [],
#  ['Sabarimala', 'BJP', 'Kerala'],
#  ['Kerala', 'Sabarimala', '2018'],
#  ['Mumbai', 'India'],
#  ['4', '2', '2'],
#  [],
#  ['2'],
#  ['Kerala', '1'],
#  ['Kerala', 'UAE'],
#  [],
#  ['Geneva', 'Chekutty'],
#  [],
#  ['Sabarimala'],
#  ['Kerala', 'NDA', 'Kerala', '2019', '13'],
#  ['Optume', 'Houselifting', 'Company', 'Kerala', '100'],
#  ['Lama', 'Zopa', '&', 'FPMT', '2'],
#  ['2'],
#  ['Kerala'],
#  [],
#  ['Kerala', '244', '65', '10'],
#  ['two', '2018', '1', '2'],
#  ['BJP', 'Sabarimala'],
#  ['Kerala'],
#  ['Amicus', 'Curiae', 'Kerala', 'Kerala', 'Govt', '2018'],
#  ['UDF', 'Kerala', 'High', 'Court', 'Kerala', '450', '1/2'],
#  ['Kerala', 'Amicus', 'Curiae', '2018'],
#  [],
#  [],
#  ['Nobel', 'Peace', 'Prize', 'Committee', 'Kerala', '2018'],
#  ['IAF'],
#  ['Kerala'],
#  ['Lok', 'Sabha', 'State', 'Govt', '¹118cr', '¹7304'],
#  ['Kerala', 'Kerala'],
#  ['Thiruvananthapuram', 'Gujarat', 'RebuildKerala', 'Better', '2001'],
#  ['Meghalaya'],
#  ['Amaravila', 'three'],
#  ['South', 'India', '31000', '600', '15000', '353'],
#  ['Modi', 'Govt', '500', '290'],
#  ['Kerala', 'Kerala', '¹31', '000', '¹2000', '¹600', '¹290'],
#  ['Kerala', '290.67', '25cr'],
#  [],
#  ['Wayanad', 'Kerala', 'IAS', 'Kerala'],
#  [],
#  ['CycloneGaja', '¹', '2', '¹', '4.50'],
#  ['2', '4.5'],
#  [],
#  ['India', 'Britain'],
#  ['Kerala', '228', 'One'],
#  ['26'],
#  ['Kerala', '¹5', '62L', '4', '¹5', '51L', '3', '¹5L', '5', '¹4', '8L', '3'],
#  ['Srikakulam', 'District'],
#  [],
#  [],
#  [],
#  ['Kerala', 'Mumbai', 'Congress'],
#  ['Sharjah', '(', 'UAE', '4th', '9yr'],
#  ['Kerala'],
#  [],
#  ['38000', '4'],
#  [],
#  ['Kochi', 'Australia', 'Kerala', '1st'],
#  ['Thrissur', 'NSS', '', 'NCC'],
#  [],
#  ['US', 'India'],
#  ['Kerala'],
#  ['DG', 'National', 'Security', 'Guards', 'NSG', '1,01', '48,077'],
#  [],
#  ['India'],
#  ['52', '1'],
#  [],
#  ['Kerala', 'Kerala', '24hours'],
#  ['Kerala', 'Kerala'],
#  ['Wynad', 'Kerala', 'Nepal', '620', '10000', 'one', '600'],
#  ['EatAtTrivandrum'],
#  ['Youth', 'Congress', 'Kerala'],
#  ['2018'],
#  ['2018'],
#  ['India'],
#  ['Kerala', '400'],
#  [],
#  ['1'],
#  ['Kozhikode'],
#  ['India'],
#  ['Kerala', '18'],
#  ['Kerala'],
#  ['Germany', '990'],
#  ['Kerala', 'Congress'],
#  ['India', 'million', '¹21', '000'],
#  [],
#  ['Canada', 'two', '50'],
#  ['Kerala', '19th'],
#  ['DYFI', '1', '2'],
#  [],
#  ['Kovalam'],
#  ['Nadi', 'Veeras', 'KeralaFloods', '175', '50', '\x80'],
#  ['Kerala', 'Flood', 'Relief', 'Fund', 'Shine', 'Star', 'FC', 'Delhi'],
#  [],
#  ['Kerala', '1027'],
#  ['Kerala'],
#  ['one'],
#  ['Ministry',
#   'of',
#   'Agriculture',
#   'and',
#   'Farmersâ',
#   'Mission',
#   'for',
#   'Integrated',
#   'Development',
#   'of',
#   'Horticulture',
#   '93.39'],
#  ['Trivandrum', 'Kerala', 'CM', 'Pinarayi', 'Vijayan', '&'],
#  ['Nadi', 'Veeras', 'KeralaFloods', '175', '50', '\x80'],
#  ['ITI', 'Training', 'Officers', 'Ernakulam', '25'],
#  [],
#  [],
#  [],
#  ['Kerala', 'India', 'Kashmir', '\x80'],
#  ['KeralaFloodsRelief',
#   'Mrs',
#   'Reena',
#   'Lanba',
#   'President',
#   'Navy',
#   'Wives',
#   'Welfare',
#   'Association',
#   'Muttinakam',
#   'village',
#   'Varapuzha',
#   'Ernakulam'],
#  [],
#  ['USA', 'India', 'United', 'States', 'of', 'America', 'India'],
#  ['UAE', 'Gulf'],
#  ['Kerala'],
#  [],
#  ['Cochin', 'International', 'Airport', 'Kochi', 'CIAL'],
#  ['ASRoma',
#   'Atalanta',
#   'Florenzi',
#   '&',
#   'Manolas',
#   '+',
#   'Schick',
#   'Kolarov',
#   '&',
#   'Pellegrini',
#   'Details',
#   '5'],
#  ['Chengannur', 'Kerala', 'Kerala'],
#  [],
#  ['Kerala', 'PCC', '1001'],
#  ['Justice', 'Kurian', 'Joseph', '&', 'K.M.Joseph', 'Kerala'],
#  ['Congress', 'Kerala', 'Kerala', 'Congress', '30'],
#  ['Kerala', 'Panjab', 'Kerala', '5th'],
#  [],
#  ['Sevadal', 'Young', 'Brigade', 'Kerala'],
#  ['India'],
#  ['Kerala'],
#  ['Parliament', 'Govt'],
#  ['India', 'two', 'one'],
#  ['Delhi',
#   'Co-operative',
#   'Housing',
#   'Finance',
#   'Corporation',
#   'Limited',
#   '(',
#   'DCHFCL',
#   ')',
#   '&',
#   'Delhi',
#   'Consumers',
#   'Cooperative',
#   'Wholesale',
#   'Store',
#   '¹9',
#   '51'],
#  ['1'],
#  [],
#  ['100'],
#  ['Kerala', 'Education', 'Kerala'],
#  [],
#  [],
#  ['Kerala', 'India', '2018'],
#  ['Supreme', 'Court', 'Delhi', 'Kerala', '27.08', '2018'],
#  ['Congress',
#   'Kerala',
#   'Chengannur',
#   'District',
#   'Alappuzha',
#   'Camelot',
#   'Convention',
#   'Centre',
#   'Alappuzha',
#   '2',
#   '28'],
#  ['10.5'],
#  ['Kerala', 'Guduru', 'Prabhas', '50', '25000'],
#  ['1cr'],
#  ['Muslim', 'Brotherhood'],
#  ['Kerala', 'Khalsa', 'Aid', 'India'],
#  ['OpsSahayata'],
#  ['Jamuna'],
#  ['Seva', 'Bharati', 'Kerala', 'Narada', 'News'],
#  ['Venezuela', '83000', '2.4', 'million'],
#  ['Israel',
#   'Kerala',
#   'Israel',
#   'Kerala',
#   'UAE',
#   'Israel',
#   '6/7',
#   '2016',
#   '21/8',
#   '2018',
#   '1st'],
#  ['Kerala'],
#  ['CPM'],
#  [],
#  ['Tamil', 'Nadu', 'Kerala', 'Flood', 'One', '200'],
#  ['Kerala'],
#  ['Congress', 'Kerala', '28'],
#  ['Geneva'],
#  [],
#  ['Kerala',
#   'Armed',
#   'Forces',
#   'for',
#   'Relief',
#   '&',
#   'Rescue',
#   'Kerala',
#   '&',
#   'Mahe',
#   '2018'],
#  ['Kerala', 'Govt', 'Kerala', '2'],
#  ['Kerala', 'Shri', 'CRPF'],
#  ['Kerala', 'Thalapathy', 'Fan', 'Post', 'Tamilnadu'],
#  ['Kerala', 'Kerala'],
#  ['Bollywood'],
#  ['Manorama', 'News'],
#  ['Congress',
#   'Thiruvananthapuram',
#   'Chengannur',
#   'Alappuzha',
#   'Wayanad',
#   '28th',
#   '29th'],
#  ['Mumbai', 'Maharashtra', 'Air', 'India', '2.5'],
#  [],
#  ['4,62', '456', '1435', '8th', '26th', '302'],
#  ['6'],
#  ['Kollam'],
#  [],
#  ['DC', 'Books', '10,000'],
#  ['Isha', 'Yoga', 'Center', 'Kerala', 'one'],
#  ['Kerala'],
#  [],
#  ['Kerala', 'KeralaFloods'],
#  ['Kerala', 'AIMIM', 'Thiruvananthapuram', 'Kerala', 'Air', 'India'],
#  ['Keralafloods', 'Republic'],
#  ['Kerala', 'Kerala'],
#  ['Purayar', 'Desam', 'Area'],
#  [],
#  ['Onam', 'Kerala', 'Kerala'],
#  ['Kerala', 'India', 'Sentinel', '2'],
#  ['Kerala', 'NCP', '25'],
#  [],
#  [],
#  [],
#  ['India'],
#  ['KeralaFloods'],
#  ['Indian', 'Army'],
#  ['Air', 'Force', 'Kerala', '2500'],
#  ['Onam', 'one'],
#  ['³àµ'],
#  ['Chengannur', 'Two', '1', '2'],
#  [],
#  [],
#  ['Thiruvananthapuram', '175'],
#  ['Central', '&', 'State', 'Govt'],
#  [],
#  ['Kerala', 'UAE', 'Indian', 'Army'],
#  ['BJP', 'Kerala'],
#  ['700', '2018'],
#  ['MPLAD', 'Ernakulam', 'District', 'Kerala', '¹1Cr'],
#  ['India', 'Kerala'],
#  ['Kerala'],
#  ['Delhi', 'One'],
#  [],
#  ['Kerala'],
#  ['Maharashtra',
#   'Govt',
#   'Kerala',
#   'Kerala',
#   'Bank',
#   'of',
#   'Maharashtra',
#   'Mantralaya',
#   'IFSC',
#   '6031297814',
#   '9',
#   '0001388'],
#  [],
#  ['Kerala', 'Sheegra'],
#  ['India', 'UAE', 'India'],
#  ['Rapid', 'Action', 'Medical', 'Team', 'Indian', 'Air', 'Force', 'Kerala'],
#  ['UAE', 'Kerala', 'Kerala', 'â', '¹700', '21', '2018'],
#  [],
#  ['South', '24x7'],
#  ['UAE', 'Kerala', '700', '2'],
#  ['Kerala'],
#  ['Kerala'],
#  ['\x80'],
#  ['UAE'],
#  ['India'],
#  ['Google', 'Abu', 'Dhabi', '1'],
#  ['Kerala', 'PMC', 'Kerala'],
#  ['Kerala', 'Kerala'],
#  ['Sonia', '', 'Rahul'],
#  ['Chengannur', 'Aranmula', 'CPM', 'Chengannur'],
#  ['Pathanamthitta', 'District', '2018'],
#  ['Kerala'],
#  ['Aranmula', 'Chengannur', 'Kerala', '6000', 'one'],
#  ['UAE', '700'],
#  ['Kerala', 'one', 'million'],
#  ['Kerala', 'India', '700'],
#  [],
#  ['"'],
#  ['Aranmula', '6000'],
#  [],
#  ['London', 'Kerala'],
#  ['Kerala', 'Kerala', 'India', 'Kerala', '600', '562.45'],
#  ['BJP'],
#  [],
#  ['50', '41', '13477', '16158'],
#  ['10,40', '688', '2,78', '781', '2,774', '5'],
#  ['44'],
#  [],
#  ['North', 'Chennai', 'Kerala', '10,000'],
#  [],
#  [],
#  ['KeralaFloods', 'Lulu', 'Group', '11', '700', '700'],
#  ['five'],
#  ['UAE', '"'],
#  [],
#  ['10'],
#  ['Israel', 'Kerala', '1st'],
#  ['Jaunpur'],
#  ['UAE', 'UAE', 'UAE', '1', '700', '21', '700Cr', '20th'],
#  ['Kerala', '¹45', '000', '2018'],
#  ['Kerala', 'Eid', 'Prayers', 'Mosque', 'India'],
#  ['India'],
#  ['MediaOne', 'Malayalam', 'News', 'Channel', 'About', 'Lorries', 'Kerala'],
#  ['one', '4000', '700'],
#  ['CRPF'],
#  ['Kochi', 'Flood'],
#  [],
#  [],
#  ['UAE', '700', '100', 'million', '2015', '9'],
#  ['Kerala', '8crs'],
#  ['Kerala', 'Univ', '', 'College', '1'],
#  ['Ernakulam', 'Kerala'],
#  ['Kottayam', 'Kerala'],
#  ['Kerala', 'Somalia'],
#  ['Xiaomi', 'India', 'Kerala'],
#  ['one'],
#  ['Kerala'],
#  ['India'],
#  [],
#  ['Peshawar', 'Zalmi', '5000'],
#  [],
#  ['Kerala', '50', '27', '31st'],
#  ['Kerala'],
#  [],
#  ['KERALA'],
#  ['Kerala'],
#  [],
#  ['Kerala', 'Govt', 'CPM', '400'],
#  ['Kerala', 'Kerala', '5'],
#  ['Paravoor', 'Ernakulam', 'District'],
#  ['Nepal'],
#  ['Kerala', '1000s'],
#  ['Kerala'],
#  [],
#  ['Kerala',
#   'United',
#   'Breweries',
#   'Radico',
#   'Khaitan',
#   'Globus',
#   'Spirits',
#   'GM',
#   'Breweries',
#   'Empee',
#   'Distilleries',
#   'Jagatjit',
#   'Industries'],
#  ['Kerala', 'Odisha', 'Kerala'],
#  ['BJP', 'Maharashtra', 'Govt', 'BJP', '100'],
#  ['UAE', 'India', 'UAE', 'India', 'Kerala', '700Cr'],
#  ['TRUTH', 'Lulu', 'Group', 'Kerala', 'UAE', '700', '700'],
#  ['Malappuram'],
#  [],
#  ['UAE', 'India'],
#  [],
#  ['Lucknow', 'Kerala', 'Indian', 'Air', 'Force', 'Trivandrum', '76'],
#  [],
#  [],
#  ['Google', 'India'],
#  ['Disaster', 'Management', '&', 'Research', 'Centre', 'Kerala', 'Kerala'],
#  ['Indian', 'Air', 'Force', 'Ottafice', 'IAF', '44'],
#  ['CIAL', 'Cochin', 'International', 'Airport', 'Kochi', '18', '14:00'],
#  ['Congress', '34'],
#  ['Kerala', 'Flood', 'Relief', 'Camps', 'Naamakkal'],
#  ['Kerala', 'LDF', '&', 'UDF', 'Keralafloods', 'India', '2', '2', 'billion'],
#  ['India'],
#  ['Cong',
#   'Kerala',
#   'Geneva',
#   'BJP',
#   'BJP',
#   'MLA',
#   '&',
#   'Maharashtra',
#   '1',
#   '2',
#   '3',
#   '4'],
#  ['UN', 'Kerala', 'Kerala', 'Keralafloods'],
#  ['Kerala', 'Karnataka'],
#  [],
#  ['14.5'],
#  ['India'],
#  ['Suriya', 'Committee'],
#  ['Kerala'],
#  ['Border',
#   'Police',
#   'Muthavajhy',
#   'Canvazhy',
#   'Chengannur',
#   'Allappujha',
#   'Kerala',
#   '27th'],
#  ['Trent', 'Bridge', 'Kerala', 'Kerala'],
#  ['Pallakad', 'Kerala'],
#  ['Kerala'],
#  ['Kerala'],
#  ['Corporation', '¹25000', '¹50000'],
#  ['Jain', 'International', 'Organisation', '¹51', '00,000'],
#  ['Jain', 'International', 'Organisation', '5'],
#  ['Kodungalloor'],
#  ['Malayalam', '70'],
#  ['Mumbai', '¹21', '000'],
#  ['Kochi', '1'],
#  ['KeralaFloods', 'Rescue', 'CPIM', '1'],
#  ['Israel', 'Embassy', 'Kerala'],
#  ['Kerala', 'two', 'two'],
#  ['Kerala'],
#  ['Kerala'],
#  ['Allapphuzha'],
#  ['India', '2FakeNews'],
#  ['Kerala', 'two', 'one'],
#  ['Kerala', '500'],
#  [],
#  ['³à', '70', '²à', '³à', '000'],
#  ['Kerala'],
#  ['Congress',
#   'Germany',
#   'Geneva',
#   'Congress',
#   'KeralaFloods',
#   'UK',
#   'Germany',
#   'two'],
#  ['Kerala', 'Border', 'Security', 'Force', 'Thrissur'],
#  ['Kerala'],
#  ['Pathanamthitta', 'Engineer', 'Regiment', '2018', '21', '227', '746'],
#  ['Kerala'],
#  [],
#  ['74', 'one', 'two'],
#  ['21/8', '2018'],
#  ['700'],
#  [],
#  ['UAE', 'Kerala', '700', '2004'],
#  ['Border',
#   'Police',
#   'Muthavajhy',
#   'Canvazhy',
#   'Chengannur',
#   'Allappujha',
#   'Kerala',
#   '27th',
#   '460',
#   '3500'],
#  ['Congress', '2016'],
#  ['Kerala'],
#  ['8'],
#  ['²à', '³à'],
#  [],
#  [],
#  ['Rashtravadi', 'Welfare', 'Fund', 'Kerala', 'NCP', 'Kerala'],
#  ['Geneva', 'UN'],
#  ['Kerala', 'Kerala'],
#  [],
#  ['Kerala', '2018'],
#  ['Umra', 'DRF', '80'],
#  ['Kerala', 'Kerala'],
#  ['¹21', '000'],
#  ['India', 'Kerala', 'New', 'Delhi', 'three'],
#  ['Salem-Chennai', 'Salem', '10,000'],
#  ['one', 'one'],
#  ['Israel'],
#  ['Navy', 'Aluva'],
#  ['Districts', 'VMI', '', 'Fan', 'Clubs', 'Kerala', '¹', '3', '14', '15'],
#  ['¹70', '15', '15', '12'],
#  ['Kerala'],
#  ['Kerala'],
#  [],
#  ['4SocialGood'],
#  ['2', '15'],
#  ['IndianNavy', '2018', '7000..twitter.com/i53wZqTsAi'],
#  ['Kerala', '3', '15', '15', '12'],
#  [],
#  ['70'],
#  ['Kerala', '15', '12'],
#  ['Thiruvananthapuram', 'Calicut'],
#  ['70Lakhs'],
#  ['Kerala', '70'],
#  ['Kerala'],
#  ['70'],
#  ['70'],
#  ['70'],
#  ['Kerala', '80', '0,000'],
#  ['Maharashtra', 'Kerala'],
#  ['Kerala', 'Chalakudy', '300'],
#  ['Air', 'Force', 'Air', 'Force', 'Kerala', '17'],
#  ['Pakistan', 'Kerala', 'India', '5000'],
#  ['Kerala'],
#  ['Air', 'Force', 'Kerala'],
#  ['Pizhala', 'Pizhala', 'Kothad', 'Moolamvelli', '2018', '4', '12', '1459'],
#  ['Malayalam'],
#  ['ITBP'],
#  ['Two', '2018'],
#  [],
#  ['Kerala', '10,000', '2'],
#  ['UAE',
#   'Union',
#   'Indian',
#   'Union',
#   'Nepal',
#   'West',
#   'Bengal',
#   'India',
#   'West',
#   'Bengal'],
#  ['30th'],
#  ['Indian', 'Army'],
#  [],
#  ['KeralaFloods', 'KeralaReliefFund', 'UAE', 'Kerala', '700'],
#  ['US', '30,000', 'one', '28thAugust'],
#  [],
#  ['UAE', 'Kerala', '700', '100'],
#  ['Kerala', 'One', 'One'],
#  ['Kerala', '1.5'],
#  ['Madurai', 'Kerala', 'Floods'],
#  ['Allapphuzha', '25/10'],
#  ["Chengannur's", 'Pandanad', 'Alappuzha'],
#  ['Kerala'],
#  ['UAE', 'Kerala', 'UAE', 'UAE', 'Kerala', '700'],
#  ['UAE', 'Govt', 'Kerala', 'Modi', 'Govt', '700', '600'],
#  ['United', 'Arab', 'Emirates', '(', 'UAE', 'Kerala', '700'],
#  ['DGCA'],
#  ['10629', '49'],
#  ['Ernakulam', '2018', '2032', '10629', '49'],
#  ['Flood', 'Relief', 'Camp'],
#  ['Sanghi', 'Kerala', 'BJP', 'Sanghi', 'Kerala', 'KERALA'],
#  ['UAE', 'VPS', '26', 'million', '50', 'one', '1000'],
#  ['thousand'],
#  ['Telangana',
#   'Gazetted',
#   'Officers',
#   'Association',
#   'Kerala',
#   'Kerala',
#   'one',
#   '10'],
#  ['Alappuzha', 'Pathanamthitta', 'Kerala', '27th'],
#  ['400', '40000', '3700', 'million', '10000', 'million', '38', 'million'],
#  ['Sanghi'],
#  ['Kerala', 'IAF', '17', '\x80'],
#  ['Kerala', '40,151', '40,151', '40k'],
#  [],
#  ['Kerala', 'Madhya', 'Pradesh', 'DGP', '1.31', '1'],
#  ['Kerala', 'Kodagu'],
#  ['Kerala', '1', '50lakhs'],
#  ['10'],
#  ['Kerala', 'one', '825'],
#  ['Kerala', 'Kerala', '400', 'one'],
#  ['Tripura', 'Kerala', '1', '20.8', '2018'],
#  ['India', 'Supreme', 'Court', 'Kerala', 'Kerala', '25,000'],
#  ['Alappuzha', 'Pathanamthitta', 'Kerala', '27th', '20.8', '2018'],
#  ['10'],
#  ['Kerala'],
#  ['Kongorpilly',
#   'Govt',
#   'Higher',
#   'Secondary',
#   'School',
#   'Koonammavu',
#   'Kerala',
#   '1200'],
#  ['Kerala'],
#  [],
#  ['2'],
#  ['Mulanthuruthy', 'Cochin'],
#  ['CPM', 'Indian', 'Army', 'Indian', 'Army', 'Army', 'Army'],
#  [],
#  ['India'],
#  ['Chennai', 'Kerala', 'Floods'],
#  [],
#  ['Ernakulam', 'Kerala'],
#  ['Kerala', 'Army', 'Facebook'],
#  ['Relief', 'Camps', 'In', 'Thirurangaadi', 'Vettam', 'School', 'Today'],
#  ['Kerala', '3', '2018'],
#  ['Kerala'],
#  ['Kerala', 'Declared', 'Central', 'Govt', '&', 'Modi'],
#  ['India', 'Kerala'],
#  ['Kerala', 'SBI'],
#  ['Comali', 'Party', 'of', 'Murderers'],
#  ['Kerala', 'Kerala', 'Kerala', '3', '1truck'],
#  ['Army', 'Navy', 'Airforce', '2', '4', '2post'],
#  [],
#  [],
#  ['KOLLAM', 'NANBANS'],
#  [],
#  [],
#  ['Geneva', 'India'],
#  ['Kerala', '400'],
#  ['Association', '5'],
#  ['Kerala'],
#  ['Kerala', 'State', '500'],
#  [],
#  ['Congress', 'Kerala', '¹5', '000', '¹35'],
#  ['Kerala'],
#  ['NDTV', 'Kerala', '1', '2'],
#  [],
#  [],
#  ['Kerala', 'India', '10,000'],
#  ['Maharashtra', 'Medical', 'Mumbai', 'Airport'],
#  ['Trivandrum', 'Bhubaneswar', 'Odisha', 'Government'],
#  ['5th'],
#  ['Challakudi', 'Thrissur', '105RAF'],
#  ['Kerala', '5â', '¹', '10â', '¹', '2,100'],
#  ['Kerala',
#   'Neft',
#   '¹à',
#   '²à',
#   '²à',
#   '¹à',
#   '¹',
#   '18,024',
#   '12024',
#   '6000',
#   '4Kerala'],
#  ['Punjab', 'Shiromani', 'Gurdwara', 'Parbandhak', 'Committee', 'Two', 'one'],
#  ['Assam'],
#  [],
#  ['KOLLAM', 'NANBANS'],
#  [],
#  ['BJYM', 'Thiruvalla', 'Town', 'Committee', 'One'],
#  [],
#  ['Kerala', '1'],
#  ['Sikh', 'Khalsa', 'Aid', 'International', 'Kerala', '2018'],
#  [],
#  [],
#  ['Kerala', 'Mersal', 'Girls', 'Fans', 'Association'],
#  ['Kerala', 'India'],
#  ['Kerala', 'State', 'Electricity', 'Board', 'Sangh'],
#  ['Southern', 'Command', '70'],
#  ['Lexus', 'Bus', 'Of', 'Kannur', 'Vijay', 'Fans'],
#  ['Kerala', 'Mumbai', 'Airport', '95'],
#  [],
#  [],
#  ['Navy', '2018'],
#  ['103', 'six'],
#  ['Sabarimala', '\x80'],
#  [],
#  ['Kottayam', 'Bangalore'],
#  ['Kerala'],
#  [],
#  ['Kerala', '¹50', '¹50', 'million'],
#  ['Kerala'],
#  ['Welfare',
#   'Association',
#   'Coimbatore',
#   'Rapid',
#   'Action',
#   'Force',
#   'RAF',
#   'Chalakudy',
#   '12'],
#  ['Odisha', 'Fire', 'Service', '245', '63', '19', '1999'],
#  ['Indian', 'Navy', 'Thrissur', 'six', '109'],
#  ['NDA', 'Kerala', '2013', '5748', '1000', '2018', '357', '920', '2', '50K'],
#  ['NRI', 'Kerala'],
#  ['Shiv', 'Sena', 'Kerala', 'one'],
#  ['Tanur'],
#  ['20000'],
#  ['Kerala', 'Kerala'],
#  ['KeralaFloodRelief', 'Naval', '2018', '1030h'],
#  [],
#  ['Idukki', 'Five', '200m', '1986'],
#  ['Aluva', '2'],
#  ['Kochi', 'two', '17'],
#  ['Kanniyakumari', 'Tamil', 'Nadu', 'Aleppey', 'Chenganur'],
#  [],
#  ['Rapid', 'Action', 'Force', '19'],
#  ['UAE', '23M', '1AED', '19Rs'],
#  ['two'],
#  [],
#  [],
#  ['Random', 'List', 'Of', 'Suriya', 'Fans', 'Club', 'Kerala'],
#  ['5'],
#  [],
#  [],
#  ['INS', 'Garuda', 'Naval', 'Air', 'Station', 'Kochi'],
#  [],
#  ['Kerala', 'Army', '17', '"'],
#  [],
#  ['Kerala'],
#  [],
#  ['47'],
#  [],
#  ['Kochi', '3', '1000', '19.8', '2018'],
#  ['Kerala'],
#  ['9'],
#  ['Gulf'],
#  [],
#  ['19.08', '2018'],
#  [],
#  ['8'],
#  ['Lakeshore',
#   'Hospital',
#   'Ernakulam',
#   'Kerala',
#   '100',
#   '20/8',
#   '18',
#   '8:',
#   '00',
#   '8129835438'],
#  [],
#  ['Kerala', '13', 'five', '536'],
#  ['Gulf'],
#  [],
#  ['Facebook'],
#  ['Kerala', 'Kodugu', '6', '3000'],
#  ['Rescue', 'Operation', 'Kerala'],
#  ['Kerala'],
#  [],
#  [],
#  ['¹3000'],
#  ['Kerala', 'Vijay', 'Online', 'Fans'],
#  ['Trivandrum', 'District', 'Committee'],
#  ['Kanpur', 'Kerala'],
#  ['Army', '9172900285', '79'],
#  ['2'],
#  ['Ernakulam'],
#  [],
#  ['India', 'Kerala'],
#  ['Kerala'],
#  ['Kerala', '27', '49'],
#  ['243', '24', '21'],
#  ['Kerala'],
#  ['UP', 'Police', 'Kerala', 'Kerala', 'one', '300'],
#  ['6.5', '40', '15,000'],
#  ['SFC', 'Brothers', 'Doing', 'Rescue', 'Works'],
#  [],
#  ['Kerala',
#   'CPM',
#   'Trivandrum',
#   'Kumily',
#   '&',
#   'Palakkad',
#   '1',
#   '2',
#   '3',
#   '4',
#   '357'],
#  ['Kerala'],
#  ['Assam', 'NRC'],
#  [],
#  ['Kerala', 'Trivandrum', '&', 'Kumily', '15'],
#  ['Kerala', '1', '2'],
#  ['Kerala', 'Mumbai', 'Airport', '30', '5'],
#  ['MERSAL',
#   'GIRLS',
#   'Fans',
#   'Association',
#   'Malappuram',
#   'District',
#   'Giving',
#   'Helpings',
#   'For',
#   'Our',
#   'Brothers'],
#  ['Kerala', 'Adoor', '9871358055'],
#  ['Vatican', 'Kerala'],
#  [],
#  [],
#  [],
#  ['Kerala', '3'],
#  ['Kochi'],
#  [')',
#   'Front',
#   'Page',
#   'of',
#   'Guardian',
#   'UK',
#   ')',
#   'Front',
#   'Page',
#   'of',
#   'The',
#   'Straits',
#   'Times',
#   'Singapore',
#   ')',
#   'Front',
#   'Page',
#   'of',
#   'Gulf',
#   'News',
#   'Dubai',
#   ')',
#   'Front',
#   'Page',
#   'of',
#   'Times',
#   'of',
#   'India',
#   'Aug',
#   'International',
#   'Newspapers',
#   '1',
#   '18',
#   '2',
#   '18',
#   '3',
#   '18',
#   '4',
#   '18'],
#  [],
#  ['Kerala'],
#  ['Kerala', 'INS', 'Mysore', 'Mumbai'],
#  ['Karyakartas', '5'],
#  ['Kerala'],
#  [],
#  [],
#  ['KERALA', 'KERALA', 'KERALA', 'Los', 'Angeles'],
#  ['Kerala', 'Kerala', '8000'],
#  ['one'],
#  ['Bengal', 'Bihar', 'Orissa', 'Assam'],
#  [],
#  ['Rapid', 'Action', 'Force', 'Erumachery', 'RAF', 'Coimbatore'],
#  [],
#  ['Cochin',
#   'University',
#   'of',
#   'Science',
#   '&',
#   'Technology',
#   'Navy',
#   '21',
#   '50000',
#   '3'],
#  [],
#  ['Bhartiya'],
#  ['Kerala', 'Kerala', '25', '50', '2.5'],
#  ['BJP', '&', 'Reliance', 'Defence', 'Kerala', '1670', '526', '1144', '600'],
#  [],
#  [],
#  ['Dist', 'Alleppey', '&', 'Pittanamthita', '15', '2000'],
#  [],
#  ['Thiruvalla', 'Kerala'],
#  [],
#  ['Chengannur', '3'],
#  ['Kerala'],
#  ['Qatar', '35'],
#  ['Kerala', 'Kerala'],
#  [],
#  ['Uttarakhand', 'Bihar', 'Kerala'],
#  ['Bihar', 'Bihar', 'BJP', 'Bihar', '500'],
#  ['Indian', 'Armed', 'Forces'],
#  ['Kerala'],
#  [],
#  ['Vengara', 'Kerala'],
#  ['Nelliyampathy'],
#  [],
#  [],
#  ['Naval', 'Base', 'Kochi', '7000'],
#  [],
#  ['India',
#   'Nepal',
#   'Bhutan',
#   'Mongolia',
#   'Kerala',
#   'India',
#   '5000',
#   '5800',
#   '5000',
#   '100'],
#  ['Kerala', 'Kerala', 'India', 'Panjab', 'Kerala'],
#  ['Kerala'],
#  ['Kerala', '100', '200', '300,000', '2,600'],
#  ['FS',
#   'Sports',
#   'Hub',
#   'Karyavattom',
#   'Greenfield',
#   'International',
#   'Stadium',
#   'Trivandrum',
#   'Kerala',
#   'One',
#   '695581',
#   '0471 710 5000'],
#  ['Indian', 'Armed', 'Forces', 'India', 'India', '67', '24', '548', 'one'],
#  ['Kerala'],
#  ['Kerala', '¹25', '¹10', '2018'],
#  ['Kerala', '25'],
#  [],
#  ['Karnataka',
#   'Ernakulam',
#   'Kottayam',
#   'Palghat',
#   'Kozhikode',
#   'Kannur',
#   'Trivandrum',
#   'Trivandrum',
#   'Kasaragod',
#   '4'],
#  [],
#  ['Chengannur', '115'],
#  ['25'],
#  ['35'],
#  ['Kerala', 'People'],
#  ['BJP', 'India', 'BJP', 'India', 'Kerala', 'India', 'BJP'],
#  ['Kerala'],
#  [],
#  ['Kerala', 'Kerala', '1/2'],
#  ['two'],
#  [],
#  ['People', 'Of', 'Kerala', '1000'],
#  ['Ministry',
#   'of',
#   'Home',
#   'Affairs',
#   'through',
#   'Press',
#   'Information',
#   'Bureau'],
#  [],
#  ['IndiaForKerala', 'Army'],
#  [],
#  ['Kerala', 'India', 'one'],
#  [],
#  [],
#  [],
#  ['Mumbai', 'Kerala'],
#  ['Kerala', 'Indian', 'Army', 'Navy', 'Airforce', '&'],
#  ['Karnataka',
#   'State',
#   'Road',
#   'Transport',
#   'Corporation',
#   'Ernakulam',
#   'Kottayam',
#   'Palghat',
#   'Kozhikode',
#   'Kannur',
#   'Trivandrum',
#   'Trivandrum',
#   'Kasaragod',
#   '4'],
#  ['ABVP', 'Relief', 'Operations', '2000'],
#  ['500', '1'],
#  [],
#  ['Kerala', '10', '2'],
#  ['Airticket', 'Kerala', 'Mangalore'],
#  ['Kerala', 'One', '2018', '"'],
#  ['Kerala', 'India', 'IBM'],
#  [],
#  ['Kerala', '2', '1'],
#  ['Qatar', 'Hamad', 'Al', 'Thani', '5', 'million', '34.9'],
#  ['Chalakudy', 'Chengannur'],
#  ['Air', 'Force', 'Alappuzha', 'Kerala'],
#  ['Congress', 'Kerala', 'India'],
#  ['Kerala'],
#  ['Kerala', 'Kerala'],
#  ['Kerala', 'BJP'],
#  ['Kerala'],
#  ['Kerala', 'Kerala'],
#  ['Karnataka', 'Kodagu', 'Kerala'],
#  [],
#  ['Chetak',
#   'Naval',
#   'Sea',
#   'King',
#   'Naval',
#   'Air',
#   'Station',
#   'INS',
#   'Garuda',
#   'Kochi'],
#  ['Indian', 'Army', 'Indian', 'Army', 'Kerala'],
#  ['Indian', 'Railways', 'Kerala', 'Central', 'Railway'],
#  ['Kerala'],
#  [],
#  [],
#  ['Kerala'],
#  ['Bhubaneswar', 'Kerala', 'Air', 'Force', '240', '18.08', '18'],
#  ['MLA', 'Syro-Malabar', 'Catholic', 'Church'],
#  ['Kerala'],
#  ['KollurMookambika',
#   'Temple',
#   'Kerala',
#   'China',
#   'Guruvayur',
#   'Temple',
#   '1',
#   '1962',
#   '1980s'],
#  ['Air', 'Force', 'Chengannur', '18.08', '18'],
#  ['MGNREGA',
#   'Mission',
#   'for',
#   'Integrated',
#   'Development',
#   'of',
#   'Horticulture',
#   'Kerala'],
#  ['Kerala', 'BJP', 'Kerala'],
#  ['Kerala', 'Kerala'],
#  [],
#  [],
#  ['Indian', 'Navy', 'Kochi', '18.8', '18'],
#  ['Supreme', 'Court', '12.45'],
#  ['Kerala'],
#  ['Kerala'],
#  [],
#  [],
#  ['Kerala', 'two', 'One'],
#  ['Kerala', 'Kerala'],
#  ['Kottiyoor', 'Kerala'],
#  ['Kerala', '11'],
#  ['Kerala', '1.5'],
#  ['Mankind'],
#  ['Nemmara', '35'],
#  ['PPP', 'Jio', 'University'],
#  ['21', '12', '4Kerala'],
#  [],
#  ['Puthukkulangara', 'Devi'],
#  ['NDRF', 'Pune', 'Kerala', 'NDRF', 'Pune', 'Three', '4', '7'],
#  ['Kerala'],
#  ['Kerala', 'Homeless', 'People', 'Volunteers', 'Kochi'],
#  ['2', '1.5'],
#  ['Pathanamthitta', 'Chenganoor'],
#  [],
#  ['WATCH', 'Indian', 'Coast', 'Guard', 'East', 'Kadangaloor', 'Kerala', '10'],
#  ['Kerala', '25'],
#  ['Cochin', 'Gujarati', '5000', '7000'],
#  ['Kerala'],
#  ['KeralaFloods',
#   'KeralaFloodRelief',
#   'Relief',
#   'Camps',
#   'Bnglor',
#   'Chennai',
#   'Kerala',
#   '2'],
#  [],
#  ['Kerala', 'Kerala', 'Kerala', '2', '¹12572', '2002'],
#  ['Kerala'],
#  ['Akshaya', 'Patra', 'Foundation', 'Kerala'],
#  ['Kerala', 'Karnataka', 'Congress'],
#  ['Kerala', 'one', '90', '167'],
#  ['1'],
#  ['DYFI', 'Kannur', '1200', '200'],
#  ['Kerala', '1', '24'],
#  ['Arunachal', 'Pradesh', 'Kerala', 'Kerala', '¹3'],
#  ['Indian', 'Armed', 'Forces', '23', '46'],
#  ['Kerala', '243', '7'],
#  ['Rajasthan', 'Kerala', '10'],
#  ['Kerala'],
#  ['Kerala', 'one'],
#  ['Hindu', 'Deities', '&', 'Swamy', 'Ayyappa', '1st', '2nd'],
#  ['9012', '12', '18024', '4', '4Kerala'],
#  ['9012', '12', '18024', '9', '9', '4Kerala'],
#  ['Indian', 'Navy', 'India', 'India', '61'],
#  ['Govt', 'of', 'India', 'Kerala'],
#  ['Government',
#   'of',
#   'Maharashtra',
#   'to',
#   'Coast',
#   'Guard',
#   'Worli',
#   'Dock',
#   '6.5'],
#  [],
#  [],
#  [],
#  ['Kerala',
#   'Vijay',
#   'Idhayam',
#   'Girls',
#   'Trivandrum',
#   'District',
#   'Committee'],
#  ['NCMC', '3,00', '000', '6,00', '000', '14,00', '000', '150', '1,00', '000'],
#  ['4Kerala'],
#  ['India', 'Kerala', 'Kerala'],
#  ['Kerala', '5', 'one'],
#  ['Kerala', 'Kolkata'],
#  [],
#  ['ITBP', 'Pittanamthita'],
#  ['Kerala', 'Kerala', 'Chhattisgarh', '7.5', '3'],
#  ['Kerala'],
#  ['KERALA', '2000'],
#  [],
#  ['Kerala', '²', '²à'],
#  ['Pune', 'Kerala', '1450K'],
#  ['Kerala'],
#  ['State', 'Kerala'],
#  ['Indian',
#   'Commercial',
#   'Pilots',
#   "'",
#   'Association',
#   'ICPA',
#   'Airbus',
#   'Boeing',
#   'Air',
#   'India',
#   'Operation',
#   'Madad',
#   '&',
#   'Operation',
#   'Sahyog',
#   'Kerala',
#   '320',
#   '787'],
#  ['The', 'New', 'York', 'Times'],
#  [],
#  ['Flood',
#   'Relief',
#   'Material',
#   'Kottayam',
#   'Kerala',
#   'BJYM',
#   'State',
#   '4Kerala'],
#  [],
#  ['Kerala'],
#  ['Bangalore', 'Cochin', 'Naval', 'Airbase', 'Coimbatore', 'Madurai', '20th'],
#  ['Kerala', 'Indian', 'Air', 'Force', 'Alappuzha'],
#  ['Cochin',
#   'Alliance',
#   'Air',
#   'Air',
#   'India',
#   'Bangalore',
#   'Cochin',
#   'Naval',
#   'Air'],
#  ['Megastar',
#   'Chiranjeevi',
#   '&',
#   'Mega',
#   'Powerstar',
#   'Ram',
#   'Charan',
#   'Kerala',
#   '25',
#   '10',
#   '1'],
#  ['BJP', 'Kerala'],
#  ['AnjanaDevi', '-', 'Rs', 'Lakh', '25', '25', '10', '1', '61'],
#  ['BJP', 'New', 'Delhi', 'BJP', 'BJP', 'Kerala'],
#  ['Thiruvananthapuram',
#   'Peroorkada',
#   'Area',
#   'Committee',
#   'Thalapathy',
#   'Fans',
#   'Collects'],
#  ['Kerala', 'Army', 'Navy', 'NDR', 'Kerala', '2000'],
#  ['Kerala'],
#  ['Google'],
#  ['1.5'],
#  ['Facebook'],
#  [],
#  ['Kerala', 'Rapid', 'Action', 'Force', '15', '5000', 'one', '100'],
#  ['15'],
#  ['Kerala', '25'],
#  ['Kerala', '15'],
#  [],
#  ['Kerala', 'Floods', 'Kerala', '1'],
#  [],
#  ['China', 'Kerala'],
#  ['¹1800', '4Kerala'],
#  [],
#  ['500', '300', '15,000', '10,000', '10'],
#  ['Kerala', '10'],
#  ['Kerala', '10'],
#  ['Kerala', '1.5'],
#  [],
#  ['PFI', 'Kerala', 'CPIM', '20000'],
#  ['Kerala', '15'],
#  ['Chowara', 'Railway', '10', '9495576688'],
#  ['Amrita',
#   'Hospital',
#   'Ernakulam',
#   'Electrical',
#   'Power',
#   '30',
#   '100HP',
#   '1000s',
#   '91',
#   '8848',
#   '790',
#   '746',
#   '2018'],
#  ['Keralafloods', '2.8', '1'],
#  ['Punjab', 'Halwara', 'Ludhiana', '1', '10', '5'],
#  ['Kerala', '50'],
#  [],
#  ['Kerala', '25'],
#  ['Kerala'],
#  ['Trivandrum', 'SMV', 'School', 'TVM'],
#  ['Kerala', 'Kerala'],
#  ['NDRF',
#   'Thrissur',
#   'Pathanamthitta',
#   'Alappuzha',
#   'Ernakulam',
#   'Idukki',
#   'Wayanad',
#   'Kozhikode',
#   '194',
#   '12',
#   '10,467',
#   '159',
#   '15',
#   '13',
#   '11',
#   '5',
#   '4',
#   '3',
#   '2'],
#  ['Chennai', '25L', '2nd', '1cr'],
#  ['one'],
#  ['Kerala', 'Chhattisgarh'],
#  ['Gujarat', 'Kerala', '10'],
#  ['KPCC', 'Flood', 'Relief', 'Committee', 'Kerala', 'Karnataka'],
#  ['Maharashtra', 'CM', 'Maharashtra', 'Govt', 'Kerala', 'Govt', '¹20'],
#  ['2', '50,000'],
#  ['Kerala'],
#  ['Indian', 'Armed', 'Forces'],
#  [],
#  ['one'],
#  [],
#  ['Kerala', 'Trivandrum', '90', '8884431226', '7204508839'],
#  ['Kerala'],
#  ['Kerala'],
#  ['Kerala', 'CPM', '8'],
#  ['82', '6400', '520', '3450', '5', '10k'],
#  ['one'],
#  [],
#  ['BJP', 'Kerala'],
#  ['KeralaFloods-Attorney', 'General', 'KK', 'Venugopal'],
#  ['Kerala', 'Kerala', 'Kashmir', '2014'],
#  ['Kerala', '19,512', '500'],
#  [],
#  ['Kerala', '¹', '20,000', '¹', '2000'],
#  [],
#  [],
#  [],
#  ['Kerala', 'Kerala', '5', '245'],
#  ['Rotary', 'Club', 'Cochin', '100'],
#  ['Indian', 'Army'],
#  ['Pattambi', 'Kerala', 'Germany'],
#  ['zero'],
#  ['Bihar', 'Kerala', 'Bihar', '10'],
#  ['Bangalore', 'Football', 'Stadium', '5PM'],
#  ['Kerala'],
#  [],
#  ['¹10k'],
#  ['Chengannur', '4', '5', '65', 'Four', '100'],
#  [],
#  [],
#  ['Kerala', 'one'],
#  ['Kerala'],
#  ['Kerala'],
#  ['Pathanamthitta',
#   '9447010000',
#   '7561072202',
#   '9947385287',
#   '9446666971',
#   '9539599959'],
#  ['Kerala', '5', '24', '4Kerala'],
#  ['Trivandrum', '1000'],
#  ['Garhwal', 'Rifles', 'Kozhincherry', '13', '91', 'two'],
#  ['Kerala', 'Ajith', 'Fans', 'Eranakulam', 'Aluva', 'UC', 'one'],
#  ['Kerala'],
#  ['Malavika', 'Two'],
#  [],
#  [],
#  [],
#  ['NDRF', '2015'],
#  ['Sabarimala', 'Kerala'],
#  ['One'],
#  ['Kerala', 'Bhubaneswar', '225', '15', '75'],
#  ['Haryana', 'Kerala', '10'],
#  ['Oman', 'Kerala', 'UAE'],
#  ['Twitter'],
#  [],
#  ['Kerala', 'Kerala', '5,000', '2,000'],
#  ['2018'],
#  ['Navy', 'Army', '&', 'CG', 'NDRF', '102', '58', '3', '800'],
#  ['Kerala', 'State', 'Government'],
#  ['4500', '500', '4'],
#  ['KeralaFloods', 'Army'],
#  ['Kerala'],
#  ['Chennai', 'Porur', 'Kerala'],
#  ['Kerala'],
#  ['Kerala', '5', '8', '24', '4Kerala'],
#  ['500', '2', '50,000'],
#  ['State', '¹19', '512'],
#  [],
#  ['Kerala'],
#  ['Kerala', '500', '100'],
#  ['Kerala'],
#  ['Kerala', 'Delhi', 'CS', 'Kerala', '10'],
#  ['2'],
#  ['Dy', 'CM', 'Kerala', 'PM', 'Delhi', 'Govt', 'Kerala', '4', '4Kerala'],
#  [],
#  ['Chengannur', 'Army', 'State', 'Govt'],
#  ['State', 'Bank', 'of', 'India', 'Kerala', '2'],
#  ['24Ã', '7'],
#  ['26'],
#  ['Karnataka', '4300', '100', '1', 'million', '324', '300'],
#  ['Mumbai', 'Kerala', 'Shell', 'Colony', 'Chembur', 'OR', 'Kerala', 'Bhavan'],
#  ['Kerala', 'Kerala', '2000', '19512', '500'],
#  ['Delhi', 'Mumbai'],
#  ['Chengannur', 'one'],
#  ['Kerala'],
#  ['Kerala', '4'],
#  [],
#  ['KERALA', 'Cochin', 'TUTICORIN', 'Cochin', '5'],
#  [],
#  [],
#  [],
#  [],
#  ['Rapid', 'Action', 'Force'],
#  ['Bengaluru', 'Kerala', 'HAL', 'airport', '20', '7259815328'],
#  ['India'],
#  ['Kochi'],
#  ['Kerala'],
#  ['Kerala', 'Kerala', '3'],
#  ['KeralaFloods'],
#  ['India'],
#  ['Indian', 'Navy', '26', '42B'],
#  ['UAE', 'Kerala', '4Kerala'],
#  [],
#  ['Kerala', '5', '12', '4Kerala'],
#  ['United', 'Arab', 'Emirates', '(', 'UAE', 'Kerala'],
#  ['Kerala', 'Kerala'],
#  ['Kerala'],
#  [],
#  ['Kochi'],
#  [],
#  ['Kochi'],
#  ['26', '32'],
#  ['Kerala', 'one'],
#  ['Hindu', 'Group', 'Kerala'],
#  ['80'],
#  ['Navy', 'Kochi'],
#  [],
#  ['Capt', 'Raj', '&', 'Co', '26', '42B', '26', '5', '32'],
#  ['Kerala', 'Guru', 'Ka', 'Langar', 'Kerala', 'Kerala'],
#  ['Thiruvananthapuram', 'Kochi'],
#  ['Goa', 'Kerala', 'five'],
#  [],
#  ['Kerala'],
#  ['Kerala',
#   'National',
#   'Crisis',
#   'Management',
#   'Committee',
#   'NDRF',
#   'Army',
#   'Navy',
#   'Air',
#   'Force'],
#  ['17.08', '18'],
#  ['Kerala',
#   'State',
#   'Kottayam',
#   'K',
#   'Raju',
#   'of',
#   'Communist',
#   'Party',
#   'Muslim',
#   'League',
#   'Germany'],
#  ['Neighbouring', 'Wayanad', '8000'],
#  ['Kerala', '700', '4,800', '9', '17.8', '18'],
#  ['Canada', 'India', 'Kerala'],
#  ['Mumbai', 'Mumbai', 'Kerala'],
#  [],
#  ['one'],
#  ['Kerala', 'BJP', 'Kerala', '100'],
#  ['ICAR', '19th'],
#  [],
#  ['Kerala', '\x80'],
#  ['Navy', '50000', 'four'],
#  [],
#  ['Kerala', '324', '100'],
#  ['UAE', 'Kerala', 'Kerala'],
#  ['MLA', 'Cherian', '50,000'],
#  ['Keralafloods'],
#  ['3.14', '9400161516'],
#  ['ITBP', 'Alleppey', '&', 'Pathanamthitta', '500', '17.08', '18'],
#  ...]
